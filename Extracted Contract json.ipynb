# %%
#Example 1 Contract

{
  "CustomerDBAName": "Barcelona Rino LLC",
  "ContractDuration": {
    "StartDate": "2022-04-01",
    "EndDate": "2025-03-31",
    "TermMonths": 36
  },
  "MonthlyForecastedUsage": {
    "January": 150,
    "February": 150,
    "March": 150,
    "April": 115,
    "May": 110,
    "June": 100,
    "July": 100,
    "August": 90,
    "September": 85,
    "October": 100,
    "November": 120,
    "December": 140
  },
  "ContractedRates": [
    {
      "Tier": "Tier One",
      "Rate": "$4.40 per Dth",
      "Duration": "2022-04-01 to 2025-03-31",
      "Type": "Fixed"
    },
    {
      "Tier": "Tier Two",
      "Rate": "Gas Market Report - Colorado Interstate Gas + $0.99 per Dth",
      "Type": "Index"
    }
  ],
  "RateClass": "Firm (Fixed Quantity): Baseload Volume",
  "UnitOfMeasurement": "Dth",
  "EnergyType": "Natural Gas",
  "ServiceAddresses": [
    {
      "Address": "2900 Larimer St, Denver, CO 80205",
      "Label": "Facility Address"
    }
  ],
  "AccountNumbers": [],
  "MeterNumbers": [],
  "Notes": [
    "Meter number field mentioned but actual meter number missing.",
    "No account number provided directly in contract."
  ]
}
# Out:
# {'CustomerDBAName': 'Barcelona Rino LLC',
#  'ContractDuration': {'StartDate': '2022-04-01',
#   'EndDate': '2025-03-31',
#   'TermMonths': 36},
#  'MonthlyForecastedUsage': {'January': 150,
#   'February': 150,
#   'March': 150,
#   'April': 115,
#   'May': 110,
#   'June': 100,
#   'July': 100,
#   'August': 90,
#   'September': 85,
#   'October': 100,
#   'November': 120,
#   'December': 140},
#  'ContractedRates': [{'Tier': 'Tier One',
#    'Rate': '$4.40 per Dth',
#    'Duration': '2022-04-01 to 2025-03-31',
#    'Type': 'Fixed'},
#   {'Tier': 'Tier Two',
#    'Rate': 'Gas Market Report - Colorado Interstate Gas + $0.99 per Dth',
#    'Type': 'Index'}],
#  'RateClass': 'Firm (Fixed Quantity): Baseload Volume',
#  'UnitOfMeasurement': 'Dth',
#  'EnergyType': 'Natural Gas',
#  'ServiceAddresses': [{'Address': '2900 Larimer St, Denver, CO 80205',
#    'Label': 'Facility Address'}],
#  'AccountNumbers': [],
#  'MeterNumbers': [],
# ...

# %%
#Example 2 Contract

{
  "CustomerDBAName": "Barcelona Waypointe LLC",
  "ContractDuration": {
    "StartDate": "2022-11-01",
    "EndDate": "2026-10-31",
    "TermMonths": 48
  },
  "MonthlyForecastedUsage": "Not directly provided in contract. Can be estimated from bills if available.",
  "ContractedRates": [
    {
      "Rate": "$0.09623 per kWh",
      "Type": "Fixed"
    }
  ],
  "RateClass": "Fixed Price Solutions",
  "UnitOfMeasurement": "kWh",
  "EnergyType": "Electricity",
  "ServiceAddresses": [
    {
      "Address": "515 West Ave Ph 5 Str 5, Norwalk, CT 06850",
      "Label": "Facility Address"
    }
  ],
  "AccountNumbers": [
    "51823187091"
  ],
  "MeterNumbers": [],
  "Notes": [
    "Monthly forecasted usage needs to be inferred from billing or sample bill.",
    "No explicit meter number provided."
  ]
}
# Out:
# {'CustomerDBAName': 'Barcelona Waypointe LLC',
#  'ContractDuration': {'StartDate': '2022-11-01',
#   'EndDate': '2026-10-31',
#   'TermMonths': 48},
#  'MonthlyForecastedUsage': 'Not directly provided in contract. Can be estimated from bills if available.',
#  'ContractedRates': [{'Rate': '$0.09623 per kWh', 'Type': 'Fixed'}],
#  'RateClass': 'Fixed Price Solutions',
#  'UnitOfMeasurement': 'kWh',
#  'EnergyType': 'Electricity',
#  'ServiceAddresses': [{'Address': '515 West Ave Ph 5 Str 5, Norwalk, CT 06850',
#    'Label': 'Facility Address'}],
#  'AccountNumbers': ['51823187091'],
#  'MeterNumbers': [],
#  'Notes': ['Monthly forecasted usage needs to be inferred from billing or sample bill.',
#   'No explicit meter number provided.']}

# %%
#Example 4 Contract

{
  "CustomerDBAName": "Barcelona Wine Bar",
  "ContractDuration": {
    "StartDate": "2022-02-01",
    "EndDate": "2026-01-31",
    "TermMonths": 48
  },
  "MonthlyForecastedUsage": {
    "February": 272,
    "March": 246,
    "April": 224,
    "May": 215,
    "June": 193,
    "July": 192,
    "August": 191,
    "September": 197,
    "October": 221,
    "November": 230,
    "December": 261,
    "January": 285
  },
  "ContractedRates": [
    {
      "Rate": "$6.898 per MMBTU",
      "Type": "Fixed"
    }
  ],
  "RateClass": "Firm Gas Supply",
  "UnitOfMeasurement": "MMBTU",
  "EnergyType": "Natural Gas",
  "ServiceAddresses": [
    {
      "Address": "515 West Ave.",
      "Label": "Service Location"
    },
    {
      "Address": "222 Summer St.",
      "Label": "Service Location"
    },
    {
      "Address": "222 Summer St. Suite 1",
      "Label": "Service Location"
    }
  ],
  "AccountNumbers": [
    "1802080190000457868",
    "4734050090000649828",
    "5590150780000533430"
  ],
  "MeterNumbers": [],
  "Notes": [
    "Service locations with account numbers provided.",
    "No specific meter numbers in contract."
  ]
}
# Out:
# {'CustomerDBAName': 'Barcelona Wine Bar',
#  'ContractDuration': {'StartDate': '2022-02-01',
#   'EndDate': '2026-01-31',
#   'TermMonths': 48},
#  'MonthlyForecastedUsage': {'February': 272,
#   'March': 246,
#   'April': 224,
#   'May': 215,
#   'June': 193,
#   'July': 192,
#   'August': 191,
#   'September': 197,
#   'October': 221,
#   'November': 230,
#   'December': 261,
#   'January': 285},
#  'ContractedRates': [{'Rate': '$6.898 per MMBTU', 'Type': 'Fixed'}],
#  'RateClass': 'Firm Gas Supply',
#  'UnitOfMeasurement': 'MMBTU',
#  'EnergyType': 'Natural Gas',
#  'ServiceAddresses': [{'Address': '515 West Ave.',
#    'Label': 'Service Location'},
#   {'Address': '222 Summer St.', 'Label': 'Service Location'},
#   {'Address': '222 Summer St. Suite 1', 'Label': 'Service Location'}],
#  'AccountNumbers': ['1802080190000457868',
#   '4734050090000649828',
#   '5590150780000533430'],
#  'MeterNumbers': [],
#  'Notes': ['Service locations with account numbers provided.',
# ...
