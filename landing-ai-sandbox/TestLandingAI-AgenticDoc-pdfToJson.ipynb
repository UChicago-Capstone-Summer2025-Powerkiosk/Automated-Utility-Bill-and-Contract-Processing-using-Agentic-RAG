# %% [markdown]
# # Test usage and effect of Landing-AI: Agentic Doc - Directly from .pdf to expected json file

# %% [markdown]
# ## Installation

# %%
pip install agentic-doc
# Out:
# Collecting agentic-doc
#   Downloading agentic_doc-0.3.0-py3-none-any.whl.metadata (19 kB)
# Collecting boto3<2.0.0,>=1.38.23 (from agentic-doc)
#   Downloading boto3-1.39.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting google-api-python-client<3.0.0,>=2.170.0 (from agentic-doc)
#   Downloading google_api_python_client-2.176.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting google-auth<3.0.0,>=2.40.2 (from agentic-doc)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib<2.0.0,>=1.2.2 (from agentic-doc)
#   Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: httpx<0.29.0,>=0.28.1 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (0.28.1)
# Collecting jsonschema<5.0.0,>=4.24.0 (from agentic-doc)
#   Downloading jsonschema-4.24.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting opencv-python-headless<5.0.0.0,>=4.11.0.86 (from agentic-doc)
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: pillow>=10.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (10.2.0)
# Collecting pillow-heif>=0.17.0 (from agentic-doc)
#   Downloading pillow_heif-1.0.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: pydantic>=2.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (2.11.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (2.10.1)
# Requirement already satisfied: pymupdf<2.0.0,>=1.25.5 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (1.25.5)
# Requirement already satisfied: pypdf<6.0.0,>=5.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (5.7.0)
# Collecting structlog<26.0.0,>=25.2.0 (from agentic-doc)
#   Downloading structlog-25.4.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: tenacity>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (9.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (4.65.0)
# Collecting types-jsonschema<5.0.0.0,>=4.24.0.20250528 (from agentic-doc)
#   Downloading types_jsonschema-4.24.0.20250708-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: typing_extensions<5.0.0,>=4.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from agentic-doc) (4.12.2)
# Collecting botocore<1.40.0,>=1.39.4 (from boto3<2.0.0,>=1.38.23->agentic-doc)
#   Downloading botocore-1.39.4-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from boto3<2.0.0,>=1.38.23->agentic-doc) (1.0.1)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3<2.0.0,>=1.38.23->agentic-doc)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.170.0->agentic-doc) (0.22.0)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client<3.0.0,>=2.170.0->agentic-doc)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client<3.0.0,>=2.170.0->agentic-doc)
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client<3.0.0,>=2.170.0->agentic-doc)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.40.2->agentic-doc) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.40.2->agentic-doc) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.40.2->agentic-doc) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<2.0.0,>=1.2.2->agentic-doc) (2.0.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29.0,>=0.28.1->agentic-doc) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29.0,>=0.28.1->agentic-doc) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29.0,>=0.28.1->agentic-doc) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29.0,>=0.28.1->agentic-doc) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.29.0,>=0.28.1->agentic-doc) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.24.0->agentic-doc) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.24.0->agentic-doc) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.24.0->agentic-doc) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.24.0->agentic-doc) (0.10.6)
# Collecting numpy<2.3.0,>=2 (from opencv-python-headless<5.0.0.0,>=4.11.0.86->agentic-doc)
#   Downloading numpy-2.2.6-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.7 MB/s eta 0:00:0000:01
# Collecting pillow>=10.0.0 (from agentic-doc)
#   Downloading pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->agentic-doc) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->agentic-doc) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.8.0->agentic-doc) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.2.1->agentic-doc) (0.21.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/lib/python3.11/site-packages (from botocore<1.40.0,>=1.39.4->boto3<2.0.0,>=1.38.23->agentic-doc) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/anaconda3/lib/python3.11/site-packages (from botocore<1.40.0,>=1.39.4->boto3<2.0.0,>=1.38.23->agentic-doc) (2.0.7)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.170.0->agentic-doc) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.170.0->agentic-doc) (5.29.5)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.170.0->agentic-doc)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.170.0->agentic-doc) (2.31.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.170.0->agentic-doc) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.40.2->agentic-doc) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2.0.0,>=1.2.2->agentic-doc) (3.3.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.11/site-packages (from anyio->httpx<0.29.0,>=0.28.1->agentic-doc) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.40.0,>=1.39.4->boto3<2.0.0,>=1.38.23->agentic-doc) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.170.0->agentic-doc) (2.0.4)
# Downloading agentic_doc-0.3.0-py3-none-any.whl (31 kB)
# Downloading boto3-1.39.4-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading google_api_python_client-2.176.0-py3-none-any.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Downloading jsonschema-4.24.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading pillow_heif-1.0.0-cp311-cp311-macosx_14_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.8 MB/s eta 0:00:0000:0100:01
# Downloading pillow-11.3.0-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading structlog-25.4.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 1.9 MB/s eta 0:00:00
# Downloading types_jsonschema-4.24.0.20250708-py3-none-any.whl (15 kB)
# Downloading botocore-1.39.4-py3-none-any.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading numpy-2.2.6-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: uritemplate, structlog, proto-plus, pillow, numpy, types-jsonschema, pillow-heif, opencv-python-headless, google-auth, botocore, s3transfer, jsonschema, google-auth-oauthlib, google-auth-httplib2, google-api-core, google-api-python-client, boto3, agentic-doc
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.40.1
#     Uninstalling google-auth-2.40.1:
#       Successfully uninstalled google-auth-2.40.1
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.38.20
#     Uninstalling botocore-1.38.20:
#       Successfully uninstalled botocore-1.38.20
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.12.0
#     Uninstalling s3transfer-0.12.0:
#       Successfully uninstalled s3transfer-0.12.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.2
#     Uninstalling jsonschema-4.19.2:
#       Successfully uninstalled jsonschema-4.19.2
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.38.20
#     Uninstalling boto3-1.38.20:
#       Successfully uninstalled boto3-1.38.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# lifelines 0.29.0 requires numpy<2.0,>=1.14.0, but you have numpy 2.2.6 which is incompatible.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.2.6 which is incompatible.
# aiobotocore 2.7.0 requires botocore<1.31.65,>=1.31.16, but you have botocore 1.39.4 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# scipy 1.10.1 requires numpy<1.27.0,>=1.19.5, but you have numpy 2.2.6 which is incompatible.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# numba 0.59.0 requires numpy<1.27,>=1.22, but you have numpy 2.2.6 which is incompatible.
# ultralytics 8.3.114 requires numpy<=2.1.1,>=1.23.0, but you have numpy 2.2.6 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.2.6 which is incompatible.
# Successfully installed agentic-doc-0.3.0 boto3-1.39.4 botocore-1.39.4 google-api-core-2.25.1 google-api-python-client-2.176.0 google-auth-2.40.3 google-auth-httplib2-0.2.0 google-auth-oauthlib-1.2.2 jsonschema-4.24.0 numpy-2.2.6 opencv-python-headless-4.12.0.88 pillow-11.3.0 pillow-heif-1.0.0 proto-plus-1.26.1 s3transfer-0.13.0 structlog-25.4.0 types-jsonschema-4.24.0.20250708 uritemplate-4.2.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Assume that the `VISION_AGENT_API_KEY` was properly requested and added to env

# %%
import os
api_key = os.getenv("VISION_AGENT_API_KEY")

# %% [markdown]
# ----

# %% [markdown]
# ## Sample Code From Github

# %%
from pydantic import BaseModel, Field
from agentic_doc.parse import parse

class ExtractedFields(BaseModel):
    employee_name: str = Field(description="the full name of the employee")
    employee_ssn: str = Field(description="the social security number of the employee")
    gross_pay: float = Field(description="the gross pay of the employee")
    employee_address: str = Field(description="the address of the employee")

results = parse("mydoc.pdf", extraction_model=ExtractedFields)
fields = results[0].extraction
metadata = results[0].extraction_metadata
print(f"Field value: {fields.employee_name}, confidence: {metadata.employee_name.confidence}")

# %% [markdown]
# ## Single File .pdf to .json extraction

# %%
import json
import requests

headers = {"Authorization": f"Basic {api_key}"}
url = "https://api.va.landing.ai/v1/tools/agentic-document-analysis"

base_pdf_path = "../landing-ai-sandbox-data/input/test_pdfs/"  # Replace with the path to the file
pdf_name = "document_0.pdf"  # Replace the file
pdf_path = f"{base_pdf_path}/{pdf_name}"

schema_path = "../schema/"
schema_name = "main_usage_schema.json"  # Replace with the JSON schema
schema_path = f"{schema_path}/{schema_name}"

with open(schema_path, "r") as file:
    schema = json.load(file)

files = [
    ("pdf", (pdf_name, open(pdf_path, "rb"), "application/pdf")),
]

payload = {"fields_schema": json.dumps(schema)}

response = requests.request("POST", url, headers=headers, files=files, data=payload)

output_data = response.json()["data"]
extracted_info = output_data["extracted_schema"]
print(extracted_info)
# Out:
# {'documentId': 'Mansfield Power and Gas, LLC Master Commercial Gas Sales Agreement', 'documentType': 'contract', 'statementDate': '2019-06-27', 'contractStart': '2019-08-01', 'contractEnd': '2020-07-31', 'customerName': 'Pangea Ventures, LLC', 'commodity': 'natural_gas', 'unit': 'therms', 'deliveryCharge': 0, 'supplyCharge': 0, 'taxCharge': 0, 'totalUsage': 2460000, 'deliveryRate': 0, 'supplyRate': 0.279, 'taxRate': 0, 'usageHistory': [{'month': 'Jan', 'usage': 500000}, {'month': 'Feb', 'usage': 450000}, {'month': 'Mar', 'usage': 300000}, {'month': 'Apr', 'usage': 200000}, {'month': 'May', 'usage': 100000}, {'month': 'June', 'usage': 65000}, {'month': 'July', 'usage': 35000}, {'month': 'Aug', 'usage': 35000}, {'month': 'Sept', 'usage': 55000}, {'month': 'Oct', 'usage': 75000}, {'month': 'Nov', 'usage': 250000}, {'month': 'Dec', 'usage': 400000}], 'locations': [{'accountNumber': '0603935855-00006', 'serviceAddress': '5250 W JACKSON BLVD, CHICAGO, IL 60644', 'meterNumber': None, 'commodity': 'natural_gas', 'rateClass': 'Choice', 'unit': 'therms', 'usageHistory': [], 'currentUsage': 0, 'deliveryCharge': 0, 'supplyCharge': 0, 'taxCharge': 0, 'deliveryRate': 0, 'supplyRate': 0.279, 'taxRate': 0, 'notes': {'addressesIncluded': [], 'accountsIncluded': [], 'aggregationNotice': '', 'estimationMethod': 'Forecast Usage based on historical data provided by Customer.'}}], 'reportType': ''}

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "data": {
#     "markdown": "Mansfield Power and Gas, LLC  \nMaster Commercial Gas Sales Agreement <!-- marginalia, from page 0 (l=0.117,t=0.040,r=0.453,b=0.073), with ID 5aa9c10a-4f9c-488d-a56e-bd22750a2614 -->\n\nlogo: Mansfield Energy, Simplified\n\nVisible Elements :\n  \u2022 Stylized \"M\" graphic on the left.\n  \u2022 Text \"Mansfield\" in bold to the right of the graphic.\n  \u2022 Tagline below \"Mansfield\" reads \"Energy, Simplified\".\n\nDesign Details :\n  \u2022 Monochrome (grayscale) color scheme.\n  \u2022 Horizontal layout: logo graphic on the left, text on the right.\n  \u2022 Tagline is in a lighter, smaller font beneath the main company name.\n\nAnalysis :\n  \u2022 The logo combines a bold, geometric \"M\" with clear, modern typography to convey a professional and streamlined brand identity for Mansfield, emphasizing simplicity in energy solutions. <!-- figure, from page 0 (l=0.746,t=0.037,r=0.886,b=0.073), with ID b9315488-b66b-4990-9bce-f4446541b939 -->\n\nTHIS MASTER COMMERCIAL GAS SALES AGREEMENT (this \u201cMaster Agreement\u201d) is entered into as of the Effective Date described below by and between Mansfield Power and Gas, LLC (\u201cSupplier\u201d), and the customer for retail natural gas supply and transportation services identified on the signature page hereto (\u201cCustomer\u201d). Each of Supplier and Customer may be referred to herein individually as a \u201cParty\u201d and collectively as the \u201cParties.\u201d <!-- text, from page 0 (l=0.117,t=0.086,r=0.893,b=0.145), with ID 530712ed-f7f4-4044-b119-c5bc90789017 -->\n\n1.      Transactions.  This Master Agreement sets forth the general terms and conditions governing transactions for the purchase, sale and transportation of natural gas and related products and services (each a \u201cTransaction\u201d) to one or more of Customer\u2019s service locations (each, a \u201cPoint of Service Location\u201d) as agreed to from time to time and specified in Exhibit B to a Transaction Confirmation. Each Transaction shall be evidenced by a written transaction confirmation (each a \u201cConfirmation\u201d) in the form set forth in Exhibit A. If Customer fails to object in writing to any term in the Confirmation within five (5) Business Days of receipt of the Confirmation, the Confirmation shall constitute the definitive written expression of the Transaction. Each Confirmation shall constitute part of and shall be subject to this Master Agreement. Nothing in this Agreement obligates either Party to enter into a Transaction at any time. This Agreement, all Exhibits thereto, and each Confirmation shall constitute a single integrated agreement between the Parties (collectively referred to as the \u201cAgreement\u201d). <!-- text, from page 0 (l=0.116,t=0.156,r=0.481,b=0.414), with ID 1a7a4dba-4faa-4ec2-a1df-8d1be42ff447 -->\n\n2.      Services. Commencing on the Delivery Start Date set forth in a Confirmation and continuing throughout the Term, Customer appoints Supplier as its exclusive agent for the supply and/or transportation of natural gas to Customer's Point of Service Locations. Subject to the terms and conditions of this Agreement, Supplier shall acquire and transport to Customer, and Customer shall purchase and receive, the Contract Quantity of natural gas of the relevant local gas distribution company (\u201cLDC\u201d) specified in a Confirmation in accordance with the terms and conditions of this Agreement. If the LDC requires Customer to install additional metering and/or related equipment at any Point of Service Location, Customer shall be solely responsible for the costs and installation thereof. Title to all natural gas hereunder shall pass from Supplier to Customer at the Delivery Point and Customer shall have the sole responsibility for transporting gas from the Delivery Point. <!-- text, from page 0 (l=0.115,t=0.425,r=0.480,b=0.654), with ID 80f6532b-5789-4e4b-99c9-a94fc259fda0 -->\n\n2.1 Customer Qualification. Customer acknowledges and agrees that  ...
#     "extracted_schema": {
#       "documentId": "Mansfield Power and Gas, LLC Master Commercial Gas Sales Agreement",
#       "documentType": "contract",
#       "statementDate": "2019-06-27",
#       "contractStart": "2019-08-01",
#       "contractEnd": "2020-07-31",
#       "customerName": "Pangea Ventures, LLC",
#       "commodity": "natural_gas",
#       "unit": "therms",
#       "deliveryCharge": 0,
#       "supplyCharge": 0,
#       "taxCharge": 0,
#       "totalUsage": 2460000,
#       "deliveryRate": 0,
#       "supplyRate": 0.279,
#       "taxRate": 0,
#       "usageHistory": [
#         {
#           "month": "Jan",
#           "usage": 500000
#         },
#         {
#           "month": "Feb",
#           "usage": 450000
#         },
#         {
#           "month": "Mar",
#           "usage": 300000
#         },
#         {
#           "month": "Apr",
#           "usage": 200000
#         },
#         {
#           "month": "May",
#           "usage": 100000
#         },
#         {
#           "month": "June",
#           "usage": 65000
#         },
#         {
#           "month": "July",
#           "usage": 35000
#         },
#         {
#           "month": "Aug",
#           "usage": 35000
#         },
#         {
#           "month": "Sept",
#           "usage": 55000
#         },
#         {
#           "month": "Oct",
#           "usage": 75000
#         },
#         {
#           "month": "Nov",
#           "usage": 250000
#         },
#         {
#           "month": "Dec",
#           "usage": 400000
#         }
#       ],
#       "locations": [
#         {
#           "accountNumber": "0603935855-00006",
#           "serviceAddress": "5250 W JACKSON BLVD, CHICAGO, IL 60644",
#           "meterNumber": null,
#           "commodity": "natural_gas",
#           "rateClass": "Choice",
#           "unit": "therms",
#           "usageHistory": [],
#           "currentUsage": 0,
#           "deliveryCharge": 0,
#           "supplyCharge": 0,
#           "taxCharge": 0,
#           "deliveryRate": 0,
#           "supplyRate": 0.279,
#           "taxRate": 0,
#           "notes": {
#             "addressesIncluded": [],
#             "accountsIncluded": [],
#             "aggregationNotice": "",
#             "estimationMethod": "Forecast Usage based on historical data provided by Customer."
#           }
#         }
#       ],
#       "reportType": ""
#     },
#     "extraction_metadata": {
#       "documentId": {
#         "value": "Mansfield Power and Gas, LLC Master Commercial Gas Sales Agreement",
#         "chunk_references": [
#           "5aa9c10a-4f9c-488d-a56e-bd22750a2614"
#         ],
#         "confidence": null
#       },
#       "documentType": {
#         "value": "contract",
#         "chunk_references": [
#           "5aa9c10a-4f9c-488d-a56e-bd22750a2614"
#         ],
#         "confidence": null
#       },
#       "statementDate": {
#         "value": "2019-06-27",
#         "chunk_references": [
#           "f48a8ae7-11e5-46f5-9eec-81b561adfd1b"
#         ],
#         "confidence": null
#       },
#       "contractStart": {
#         "value": "2019-08-01",
#         "chunk_references": [
#           "58b8f51f-4a2a-4546-b3c1-a8da1ba4beb2"
#         ],
#         "confidence": null
#       },
#       "contractEnd": {
#         "value": "2020-07-31",
#         "chunk_references": [
#           "58b8f51f-4a2a-4546-b3c1-a8da1ba4beb2"
#         ],
#         "confidence": null
#       },
#       "customerName": {
#         "value": "Pangea Ventures, LLC",
#         "chunk_references": [
#           "60ed5685-6c85-4281-b9ff-f2d309b6b1b2",
#           "f48a8ae7-11e5-46f5-9eec-81b561adfd1b"
#         ],
#         "confidence": 0.8332879788842156
#       },
#       "commodity": {
#         "value": "natural_gas",
#         "chunk_references": [
#           "f48a8ae7-11e5-46f5-9eec-81b561adfd1b",
#           "58b8f51f-4a2a-4546-b3c1-a8da1ba4beb2"
#         ],
#         "confidence": null
#       },
#       "unit": {
#         "value": "therms",
#         "chunk_references": [
#           "ba4b93d6-9b30-479d-b929-6e4b4570abcb",
#           "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#         ],
#         "confidence": null
#       },
#       "deliveryCharge": {
#         "value": 0,
#         "chunk_references": [],
#         "confidence": null
#       },
#       "supplyCharge": {
#         "value": 0,
#         "chunk_references": [],
#         "confidence": null
#       },
#       "taxCharge": {
#         "value": 0,
#         "chunk_references": [],
#         "confidence": null
#       },
#       "totalUsage": {
#         "value": 2460000,
#         "chunk_references": [
#           "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#         ],
#         "confidence": null
#       },
#       "deliveryRate": {
#         "value": 0,
#         "chunk_references": [],
#         "confidence": null
#       },
#       "supplyRate": {
#         "value": 0.279,
#         "chunk_references": [
#           "ba4b93d6-9b30-479d-b929-6e4b4570abcb"
#         ],
#         "confidence": 1.0
#       },
#       "taxRate": {
#         "value": 0,
#         "chunk_references": [],
#         "confidence": null
#       },
#       "usageHistory": [
#         {
#           "month": {
#             "value": "Jan",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 500000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Feb",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 450000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Mar",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 300000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Apr",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 200000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "May",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 100000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "June",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 65000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "July",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 35000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Aug",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 35000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Sept",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 55000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Oct",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 75000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Nov",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 250000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         },
#         {
#           "month": {
#             "value": "Dec",
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usage": {
#             "value": 400000,
#             "chunk_references": [
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           }
#         }
#       ],
#       "locations": [
#         {
#           "accountNumber": {
#             "value": "0603935855-00006",
#             "chunk_references": [
#               "40d13a14-b9d0-4ddd-9f12-00f41d6494fc"
#             ],
#             "confidence": null
#           },
#           "serviceAddress": {
#             "value": "5250 W JACKSON BLVD, CHICAGO, IL 60644",
#             "chunk_references": [
#               "40d13a14-b9d0-4ddd-9f12-00f41d6494fc"
#             ],
#             "confidence": null
#           },
#           "meterNumber": {
#             "value": null,
#             "chunk_references": [],
#             "confidence": null
#           },
#           "commodity": {
#             "value": "natural_gas",
#             "chunk_references": [
#               "40d13a14-b9d0-4ddd-9f12-00f41d6494fc"
#             ],
#             "confidence": null
#           },
#           "rateClass": {
#             "value": "Choice",
#             "chunk_references": [
#               "40d13a14-b9d0-4ddd-9f12-00f41d6494fc"
#             ],
#             "confidence": null
#           },
#           "unit": {
#             "value": "therms",
#             "chunk_references": [
#               "ba4b93d6-9b30-479d-b929-6e4b4570abcb",
#               "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#             ],
#             "confidence": null
#           },
#           "usageHistory": [],
#           "currentUsage": {
#             "value": 0,
#             "chunk_references": [],
#             "confidence": null
#           },
#           "deliveryCharge": {
#             "value": 0,
#             "chunk_references": [],
#             "confidence": null
#           },
#           "supplyCharge": {
#             "value": 0,
#             "chunk_references": [],
#             "confidence": null
#           },
#           "taxCharge": {
#             "value": 0,
#             "chunk_references": [],
#             "confidence": null
#           },
#           "deliveryRate": {
#             "value": 0,
#             "chunk_references": [],
#             "confidence": null
#           },
#           "supplyRate": {
#             "value": 0.279,
#             "chunk_references": [
#               "ba4b93d6-9b30-479d-b929-6e4b4570abcb"
#             ],
#             "confidence": 1.0
#           },
#           "taxRate": {
#             "value": 0,
#             "chunk_references": [],
#             "confidence": null
#           },
#           "notes": {
#             "addressesIncluded": [],
#             "accountsIncluded": [],
#             "aggregationNotice": {
#               "value": "",
#               "chunk_references": [],
#               "confidence": null
#             },
#             "estimationMethod": {
#               "value": "Forecast Usage based on historical data provided by Customer.",
#               "chunk_references": [
#                 "9303ea9a-1ee0-4215-adb0-00bbf99a1870"
#               ],
#               "confidence": null
#             }
#           }
#         }
#       ],
#       "reportType": {
#         "value": "",
#         "chunk_references": [],
#         "confidence": null
#       }
#     },
#     "chunks": [
#       {
#         "text": "Mansfield Power and Gas, LLC  \nMaster Commercial Gas Sales Agreement",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11660179495811462,
#               "t": 0.0397963747382164,
#               "r": 0.4528023302555084,
#               "b": 0.07299566268920898
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "5aa9c10a-4f9c-488d-a56e-bd22750a2614"
#       },
#       {
#         "text": "logo: Mansfield Energy, Simplified\n\nVisible Elements :\n  \u2022 Stylized \"M\" graphic on the left.\n  \u2022 Text \"Mansfield\" in bold to the right of the graphic.\n  \u2022 Tagline below \"Mansfield\" reads \"Energy, Simplified\".\n\nDesign Details :\n  \u2022 Monochrome (grayscale) color scheme.\n  \u2022 Horizontal layout: logo graphic on the left, text on the right.\n  \u2022 Tagline is in a lighter, smaller font beneath the main company name.\n\nAnalysis :\n  \u2022 The logo combines a bold, geometric \"M\" with clear, modern typography to convey a professional and streamlined brand identity for Mansfield, emphasizing simplicity in energy solutions.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.7457286715507507,
#               "t": 0.03722845017910004,
#               "r": 0.8860310912132263,
#               "b": 0.07307282835245132
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "figure",
#         "chunk_id": "b9315488-b66b-4990-9bce-f4446541b939"
#       },
#       {
#         "text": "THIS MASTER COMMERCIAL GAS SALES AGREEMENT (this \u201cMaster Agreement\u201d) is entered into as of the Effective Date described below by and between Mansfield Power and Gas, LLC (\u201cSupplier\u201d), and the customer for retail natural gas supply and transportation services identified on the signature page hereto (\u201cCustomer\u201d). Each of Supplier and Customer may be referred to herein individually as a \u201cParty\u201d and collectively as the \u201cParties.\u201d",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11713549494743347,
#               "t": 0.0857677161693573,
#               "r": 0.8926467895507812,
#               "b": 0.14472344517707825
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "530712ed-f7f4-4044-b119-c5bc90789017"
#       },
#       {
#         "text": "1.      Transactions.  This Master Agreement sets forth the general terms and conditions governing transactions for the purchase, sale and transportation of natural gas and related products and services (each a \u201cTransaction\u201d) to one or more of Customer\u2019s service locations (each, a \u201cPoint of Service Location\u201d) as agreed to from time to time and specified in Exhibit B to a Transaction Confirmation. Each Transaction shall be evidenced by a written transaction confirmation (each a \u201cConfirmation\u201d) in the form set forth in Exhibit A. If Customer fails to object in writing to any term in the Confirmation within five (5) Business Days of receipt of the Confirmation, the Confirmation shall constitute the definitive written expression of the Transaction. Each Confirmation shall constitute part of and shall be subject to this Master Agreement. Nothing in this Agreement obligates either Party to enter into a Transaction at any time. This Agreement, all Exhibits thereto, and each Confirmation shall constitute a single integrated agreement between the Parties (collectively referred to as the \u201cAgreement\u201d).",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11624456942081451,
#               "t": 0.15588681399822235,
#               "r": 0.4814271330833435,
#               "b": 0.41371041536331177
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "1a7a4dba-4faa-4ec2-a1df-8d1be42ff447"
#       },
#       {
#         "text": "2.      Services. Commencing on the Delivery Start Date set forth in a Confirmation and continuing throughout the Term, Customer appoints Supplier as its exclusive agent for the supply and/or transportation of natural gas to Customer's Point of Service Locations. Subject to the terms and conditions of this Agreement, Supplier shall acquire and transport to Customer, and Customer shall purchase and receive, the Contract Quantity of natural gas of the relevant local gas distribution company (\u201cLDC\u201d) specified in a Confirmation in accordance with the terms and conditions of this Agreement. If the LDC requires Customer to install additional metering and/or related equipment at any Point of Service Location, Customer shall be solely responsible for the costs and installation thereof. Title to all natural gas hereunder shall pass from Supplier to Customer at the Delivery Point and Customer shall have the sole responsibility for transporting gas from the Delivery Point.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11535151302814484,
#               "t": 0.42462190985679626,
#               "r": 0.48025625944137573,
#               "b": 0.653512179851532
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "80f6532b-5789-4e4b-99c9-a94fc259fda0"
#       },
#       {
#         "text": "2.1 Customer Qualification. Customer acknowledges and agrees that Supplier's duty to provide natural gas under any Confirmation that would require the use of an LDC's facilities is contingent upon the applicable Customer Point of Service Location qualifying for the LDC's appropriate rate or tariff schedule that would permit the use of the LDC's facilities for delivering the natural gas to that Customer Point of Service Location.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.14475004374980927,
#               "t": 0.6605373620986938,
#               "r": 0.474057137966156,
#               "b": 0.7681941986083984
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "778e4585-39cd-42d1-a817-b22b71398ccc"
#       },
#       {
#         "text": "2.2 Nominations. The Parties shall coordinate nomination activities such that the deadlines of the transporter of gas by a gas gathering or pipeline company or LDC (each a \u201cTransporter\u201d) may be met. If Customer or the LDC fails to provide Supplier with a usage nomination for any month in a timely manner, Supplier (i) may establish a nomination for such month in a commercially reasonable manner based on Customer\u2019s historical",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.14611245691776276,
#               "t": 0.7696805000305176,
#               "r": 0.47418683767318726,
#               "b": 0.8923876285552979
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "8030fe8b-690e-449f-b880-b5752ca3210a"
#       },
#       {
#         "text": "usage data available to Supplier, and (ii) shall have  \nthe right to use and rely on such nomination unless  \nnotified otherwise by Customer or the LDC. If  \nSupplier or Customer becomes aware that actual  \ndeliveries are greater or lesser than the quantity of gas  \nconfirmed by a Transporter, such Party shall promptly  \nnotify the other Party.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5587329864501953,
#               "t": 0.15548652410507202,
#               "r": 0.8860510587692261,
#               "b": 0.250354528427124
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "6593b861-dde6-4bbe-93c0-b14468a81117"
#       },
#       {
#         "text": "2.3 Imbalances. The Parties shall use commercially reasonable efforts to avoid imposition of any fees, penalties, cash-outs, costs or charges (in cash or in kind) assessed by a Transporter for failure to satisfy balancing and/or nomination requirements (\u201cImbalance Charges\u201d). If Supplier or Customer receives an invoice from a Transporter that includes Imbalance Charges, the Parties shall determine the validity and cause of such Imbalance Charges. The Party causing the imposition of the Imbalance Charges will be responsible to pay such Imbalance Charges.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5581887364387512,
#               "t": 0.25276726484298706,
#               "r": 0.8856348395347595,
#               "b": 0.4034121036529541
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "21105653-7705-485a-bc7d-e37b67af6ecd"
#       },
#       {
#         "text": "2.4 Transporter Restrictions. If either Party receives an operational flow order or any other usage or operating instructions, restrictions or similar notice (each an \u201cOFO\u201d) from a Transporter requiring action to be taken in connection with the t r a n s p o r t a t i o n o r consumption of gas pursuant to a Transaction, such Party will use commercially reasonable efforts to notify the other Party of such event in a timely manner. Such notice may be given by electronic means. Each Party will take all commercially reasonable actions required by the OFO within the time prescribed. If OFO penalties, charges, fees, costs or expenses result from the actions or inactions of one Party, then such Party shall be solely responsible for any such penalties, charges, fees, costs or expenses. Both parties agree that OFOs may require one or both parties to buy or sell quantities of natural gas in the then-current market conditions, which may be appreciably higher or lower than the Contract Price specified in a Transaction. If S u p p l i e r is responsible for nominations and balancing on a Transporter imposing an OFO or similar restriction, S u p p l i e r may (but is not required to) increase or decrease nominations, as appropriate, to avoid penalties.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.556075394153595,
#               "t": 0.40516403317451477,
#               "r": 0.8859636187553406,
#               "b": 0.7196218967437744
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "26149dd7-b860-477f-8192-0273a47826e5"
#       },
#       {
#         "text": "3.      Defined Terms.  Capitalized terms not otherwise defined herein shall have the meaning set forth in Section 30.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.525236964225769,
#               "t": 0.7194665670394897,
#               "r": 0.8887554407119751,
#               "b": 0.750529408454895
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "343ae204-8426-44fe-8a12-56db32ae7738"
#       },
#       {
#         "text": "4.     Pricing.  The price for the natural gas delivered hereunder (the \u201cContract Price\u201d) is set forth in a Confirmation, based upon Customer\u2019s Forecast Usage data, and applies to all natural gas covered under such Confirmation and includes charges for the supply, nomination and balancing associated with the transportation of natural gas, as specified in such Confirmation and in Section 11 herein.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5257802605628967,
#               "t": 0.7507310509681702,
#               "r": 0.8904650807380676,
#               "b": 0.8449169993400574
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "570c9133-d5d9-416a-bd72-f981709e6323"
#       },
#       {
#         "text": "5.      Billing and Payment.\n    5.1 General Billing and Payment Terms: Supplier shall provide monthly invoices, either through utility",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.525749921798706,
#               "t": 0.8449341058731079,
#               "r": 0.8912333250045776,
#               "b": 0.890533447265625
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "bbf931b6-1e07-404f-9f95-3d22a5484109"
#       },
#       {
#         "text": "Last modified 4.26.2016",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11734504997730255,
#               "t": 0.9076452255249023,
#               "r": 0.23029135167598724,
#               "b": 0.9216756820678711
#             },
#             "page": 0
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "4a8c13aa-17f6-4a5c-8246-cf87fa4e11f0"
#       },
#       {
#         "text": "Summary : This image shows a company logo for Mansfield, including a stylized \"M\" graphic and the tagline \"Energy. Simplified.\"\n\nlogo: Mansfield Energy. Simplified.\n  Graphic Elements :\n    \u2022 Stylized \"M\" formed by geometric shapes on the left.\n    \u2022 To the right, the word \"Mansfield\" in bold, sans-serif font.\n    \u2022 Below \"Mansfield,\" the tagline \"Energy. Simplified.\" in lighter, smaller text.\n  Text :\n    \u2022 \"Mansfield\"\n    \u2022 \"Energy. Simplified.\"\n  Layout & Dimensions :\n    \u2022 Logo is horizontally oriented, with the graphic on the left and text on the right.\n    \u2022 Tagline is directly beneath the company name, aligned left.\n  Analysis :\n    \u2022 The logo uses a clean, modern design to convey professionalism and simplicity, consistent with the tagline.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.8126974701881409,
#               "t": 0.02463270165026188,
#               "r": 0.9519637227058411,
#               "b": 0.061086542904376984
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "figure",
#         "chunk_id": "a9a111fb-dac6-40e7-8a62-24635bf062a0"
#       },
#       {
#         "text": "Master Commercial Gas Sales Agreement",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11489854753017426,
#               "t": 0.060888614505529404,
#               "r": 0.3825334906578064,
#               "b": 0.07557891309261322
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "48809e8e-2be5-4ee1-a263-27d77a72a508"
#       },
#       {
#         "text": "consolidated billing (\u201cUCB\u201d), supplier consolidated billing (\u201cSCB\u201d) or a Dual Billing Option (\u201cDBO\u201d), at its sole discretion to the extent permitted by law. Supplier may estimate bills in cases where actual billing determinants are unavailable. The billed quantity will then be adjusted to the actual quantity on the following Month\u2019s billing or as soon thereafter as actual delivery information is available. Customer shall pay all amounts owing by the Due Date specified in a Confirmation. Supplier shall credit account for all overpayments. Late payments shall incur interest charges at a rate of interest equal to the lower of a per annum rate of one and one-half percent per month (1.5%) or the maximum applicable lawful interest rate. In any instance where any payment to Supplier is declined by the issuing institution, Customer shall be assessed a non-sufficient funds charge of $35 or the maximum allowed under applicable law (whichever is less) per declined payment. Customer shall be liable for all costs incurred by Supplier, including reasonable attorneys\u2019 fees, for collections on accounts greater than thirty (30) calendar days past due.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.14428448677062988,
#               "t": 0.08985792100429535,
#               "r": 0.47845304012298584,
#               "b": 0.3689119219779968
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "c0e06f12-79ee-453b-b02f-a8e99b6bb76f"
#       },
#       {
#         "text": "5.2 Disputes and Adjustments of Invoices: \nCustomer may dispute, in good faith and in writing, the correctness of any invoice. In the event that an invoice or portion thereof is disputed, payment of the undisputed portion of the invoice shall be made by the Due Date specified on a Confirmation, with notice of the dispute given to Supplier in writing and stating the amount and basis for the dispute. Supplier and Customer agree to use good faith and reasonable efforts to resolve any such billing/invoice dispute within thirty calendar (30) days of Supplier's receipt of Customer's written notice of any such dispute. Upon resolution of the dispute, any required payment shall be made within ten (10) Business Customer must provide Supplier with written notice of any disputed charge(s) on or prior to the Due Date of the invoice or it will be deemed to have waived its rights to dispute such a charge. In addition, Supplier shall not retroactively charge any additional amounts to any timely paid Customer invoice, provided the aforementioned shall not limit Supplier's ability to adjust Customer's invoice as provided in Section 5.1 herein.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.14452214539051056,
#               "t": 0.36877018213272095,
#               "r": 0.47812706232070923,
#               "b": 0.6447020173072815
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "d6d13087-e9bd-4afe-b21b-d7332439df84"
#       },
#       {
#         "text": "5.3  Payments: The default method of payment shall be through the Automated Clearing House (\"ACH\") Recurring Payment Authorization attached herein or provided separately at Customer's request. Customer agrees to provide ACH processing details required to process such payments. No processing fee shall be assessed by Supplier when using ACH recurring payments.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.14503107964992523,
#               "t": 0.6442120671272278,
#               "r": 0.4774441719055176,
#               "b": 0.7488482594490051
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "cd53a664-cc54-425a-bfcf-c8ae6f9343a3"
#       },
#       {
#         "text": "6.      Term. The term of this Master Agreement will commence on the Effective Date and, unless terminated earlier as provided in this Master Agreement, will continue until terminated by either Party upon thirty (30) days prior written notice to the other Party; provided this Master Agreement shall remain in full force and effect during the term of any Confirmation. Each Confirmation shall set forth the applicable \u201cDelivery Period\u201d or term during which deliveries of natural gas are to be made. Supplier shall not be liable for any failure to enroll or drop a Point of Service Location by any applicable start and end date(s) set forth in the Confirmation",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11542299389839172,
#               "t": 0.7492871284484863,
#               "r": 0.47765931487083435,
#               "b": 0.8972243070602417
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "53d6d005-f721-4599-8e93-dd9bebcc8b83"
#       },
#       {
#         "text": "Last Modified 4.17.2017",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11688631027936935,
#               "t": 0.9144204258918762,
#               "r": 0.2285943329334259,
#               "b": 0.9267495274543762
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "618e7ec7-e53b-4cd8-a85a-d819fa1110c7"
#       },
#       {
#         "text": "2",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.46519115567207336,
#               "t": 0.9240646958351135,
#               "r": 0.4797693192958832,
#               "b": 0.9379755854606628
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "0117a26b-01c8-466d-94e3-c102b0df777a"
#       },
#       {
#         "text": "due to circumstances beyond its control.  Further, all\nobligations regarding indemnity, payment of Taxes, limitations\nof liability, remedies afforded to the Parties after default and\nearly termination, confidentiality obligations, and waivers\nsurvive for the period of the applicable statute of limitations.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5250235199928284,
#               "t": 0.08817866444587708,
#               "r": 0.8865514397621155,
#               "b": 0.15565921366214752
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "472ec1d6-204d-4788-90a9-a7d2facf1204"
#       },
#       {
#         "text": "7.    Renewal of Agreement.  Unless otherwise set forth on Exhibit C, not less than thirty (30) days prior to the anticipated expiration date of the then current relevant Delivery Period, Supplier may provide a Confirmation renewal notice electronically or otherwise in writing containing proposed pricing, terms and conditions for a new Confirmation (the \u201cRenewal Notice\u201d). If, following termination or expiration of any Confirmation, any of Customer\u2019s Point of Service Locations remain designated by any LDC as being served by Supplier, then Supplier may either (a) continue to serve such Point of Service Location on a month-to-month holdover basis (each, a \u201cHoldover Term\u201d).  Any such Holdover Term may be terminated by either party upon no less than thirty days written notice, unless otherwise expressly provided herein. The price payable during any Holdover Term shall be based on a variable rate, and may change monthly due to current and predicted weather patterns, retail competition, wholesale natural gas costs, fluctuations in natural gas supply and demand, industry regulations, pricing strategies, costs to serve customers, and many other factors. Variable rate agreements will automatically renew on a month-to-month basis and can be canceled at any time by either party without any early termination fee. This Agreement shall continue to govern the provision of service during any Holdover Term.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5255149602890015,
#               "t": 0.15761443972587585,
#               "r": 0.8870381116867065,
#               "b": 0.4805881083011627
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "7900ca8b-4810-4199-a1d0-5bad284f9adc"
#       },
#       {
#         "text": "8.      Performance Assurance. If either party (\"X\") has reasonable grounds for insecurity regarding the performance of any obligation under this Contract (whether or not then due) by the other party (\"Y\") (including, without limitation, the occurrence of a material change in the creditworthiness of Y or its Guarantor, if applicable), X may demand Performance Assurance. Performance Assurance shall mean sufficient security in the form, amount, for a term, and from an issuer, all as reasonably acceptable to X, including, but not limited to cash, a standby irrevocable letter of credit, a prepayment, a security interest in an asset or guaranty. Y hereby grants to X a continuing first priority security interest in, lien on, and right of ~~setoff against all Performance Assurance in the form of~~ cash transferred by Y to X pursuant to this Section 8. Upon the return by X to Y of such Performance Assurance, the security interest and lien granted hereunder on that Performance Assurance shall be released automatically and, to the extent possible, without any further action by either party.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5252100229263306,
#               "t": 0.4818187355995178,
#               "r": 0.8872137069702148,
#               "b": 0.7315252423286438
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "8c0f1a0f-e81a-4f03-ad79-465c7d500e55"
#       },
#       {
#         "text": "9.      Consent to Disclosure.  Customer designates Supplier as an authorized recipient of Customer's account, billing and usage information. Customer consents to the disclosure by each LDC to Supplier of certain basic information about Customer including: account number, meter number, meter read data, rate class, natural gas usage, billing and payment information, account name, service address, billing address, and telephone number.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5256748795509338,
#               "t": 0.731876790523529,
#               "r": 0.8872502446174622,
#               "b": 0.8370286822319031
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "18ccc53f-5382-4988-b238-a32a33545ba0"
#       },
#       {
#         "text": "10.  **Transportation.**  Customer agrees and acknowledges that Supplier does not own or control any of the transmission or distribution facilities used to transport natural gas to the Point of Service Location(s). The LDC has the",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.5266722440719604,
#               "t": 0.8380438685417175,
#               "r": 0.8881170749664307,
#               "b": 0.8951132893562317
#             },
#             "page": 1
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "c861105f-0d13-4398-a02b-522fff1d5a64"
#       },
#       {
#         "text": "logo: Mansfield Energy Simplified\n\nVisible Elements : \n  \u2022 Stylized \"M\" graphic on the left.\n  \u2022 Text \"Mansfield\" in bold to the right of the graphic.\n  \u2022 Tagline \"Energy. Simplified.\" in lighter, smaller font below \"Mansfield\".\n\nDesign & Placement : \n  \u2022 Monochrome (gray-scale) color scheme.\n  \u2022 Horizontal layout: graphic on the left, text on the right.\n  \u2022 Tagline is aligned under the main company name.\n\nAnalysis : \n  \u2022 The logo uses a bold, geometric \"M\" to create a strong brand identity, with the tagline \"Energy. Simplified.\" suggesting a focus on making energy solutions straightforward for customers.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.8164166808128357,
#               "t": 0.02468038909137249,
#               "r": 0.9547619223594666,
#               "b": 0.061340928077697754
#             },
#             "page": 2
#           }
#         ],
#         "chunk_type": "figure",
#         "chunk_id": "643dc9a6-3393-425f-a5df-b47e94d8087c"
#       },
#       {
#         "text": "Master Commercial Gas Sales Agreement",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.1179661899805069,
#               "t": 0.05907135456800461,
#               "r": 0.3853733539581299,
#               "b": 0.07428862899541855
#             },
#             "page": 2
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "238c39aa-4361-4354-a1d7-548835c5ba70"
#       },
#       {
#         "text": "responsibility to deliver the natural gas to the Point of Service\nLocation(s). Supplier has no obligation, liability, or\nresponsibility for the operations of the LDC, for the interruption\nof service, or for the LDC's failure to deliver natural gas to the\nPoint of Service Location(s).",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11870281398296356,
#               "t": 0.08832212537527084,
#               "r": 0.4801366925239563,
#               "b": 0.15510490536689758
#             },
#             "page": 2
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "33a64bb8-81e7-45e2-82a3-c7938afab149"
#       },
#       {
#         "text": "11.        Point of Service Location Usage.  Prior to entering into a Transaction, Customer will provide to Supplier information reasonably required to substantiate its usage requirements, including information regarding its meter/account numbers, historical/projected usage for a period of at least one year, time of use, hours of operation, and LDC rate classes, which in substantial part form the basis for the calculation of charges for any Transaction.  Customer shall provide Supplier at least sixty (60) calendar days prior written notice prior to removing any Point of Service Location from service hereunder as a result of reducing or ceasing operations at such Point of Service Location; including, but not limited to, closing any Point of Service Location or the sale of any Point of Service Location to an unrelated third party.  Customer shall use commercially reasonable efforts to operate Customer\u2019s Facilities such that natural gas consumption is consistent with Customer\u2019s Forecast Usage.  Customer shall notify Supplier as soon as practicable of: (i) any revision to the Forecast Usage; (ii) all scheduled or unscheduled outages or anticipated changes in usage; (iii) any anticipated Material Usage Deviations; and (iv) any removal of a Customer\u2019s Point of Service Location from service hereunder during the Delivery Period specified in a Transaction.  Customer shall be responsible to Supplier for any additional costs and losses incurred by Supplier arising from (i), (ii), (iii) or (iv); provided that Supplier shall use commercially reasonable efforts to mitigate any such costs after receipt of such notice.  Supplier may within ten (10) days of receipt of Customer\u2019s notice of a Material Usage Deviation, assess the changes in Customer\u2019s usage and if applicable, declare an Effective Removal of the affected Point of Service Location(s).",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.11744348704814911,
#               "t": 0.15594883263111115,
#               "r": 0.48045480251312256,
#               "b": 0.583620011806488
#             },
#             "page": 2
#           }
#         ],
#         "chunk_type": "text",
#         "chunk_id": "6fe13d0a-b542-4740-9889-8a9cad7a19a9"
#       },
#       {
# ...
#         "grounding": [
#           {
#             "box": {
#               "l": 0.14573878049850464,
#               "t": 0.09290459752082825,
#               "r": 0.9639214873313904,
#               "b": 0.8979208469390869
#             },
#             "page": 12
#           }
#         ],
#         "chunk_type": "table",
#         "chunk_id": "795c899e-e374-4a5d-9437-c3a0266ac807"
#       },
#       {
#         "text": "Exhibit B: Point of Service Locations  \nMaster Commercial Gas Sales Agreement",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.05861140042543411,
#               "t": 0.6782212257385254,
#               "r": 0.10314460843801498,
#               "b": 0.897444486618042
#             },
#             "page": 13
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "15502f55-ae9a-4c32-9813-91e8a7e79fdb"
#       },
#       {
#         "text": "Summary : This image shows a vertically oriented logo for \"Mansfield Money Simplified\" with a stylized \"M\" graphic.\n\nlogo: Mansfield Money Simplified\n\nLogo Elements : \n  \u2022 The word \"Mansfield\" is written vertically in bold, grey text.\n  \u2022 The tagline \"Money Simplified\" appears in lighter, smaller text to the right of \"Mansfield\".\n  \u2022 A large, stylized \"M\" graphic is positioned at the bottom, rendered in grey.\n\nDimensions & Placement : \n  \u2022 The logo is vertically stacked, with text above the \"M\" graphic.\n  \u2022 All elements are aligned along a central vertical axis.\n\nAnalysis : \n  \u2022 The logo uses a minimalist, monochrome design to convey professionalism and simplicity, consistent with the tagline \"Money Simplified\".",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.05696205049753189,
#               "t": 0.25962772965431213,
#               "r": 0.10823655873537064,
#               "b": 0.37060925364494324
#             },
#             "page": 13
#           }
#         ],
#         "chunk_type": "figure",
#         "chunk_id": "0348d295-4346-4610-a3e5-28cc6a239347"
#       },
#       {
#         "text": "<table><thead><tr><th>Account Name</th><th>Service Address</th><th>City</th><th>State</th><th>Zip</th><th>Utility</th><th>Utility Account #</th><th>Rate Class #</th></tr></thead><tbody><tr><td>Pangea Ventures, LLC</td><td>7901 S WOODLAWN AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60619</td><td>Peoples</td><td>0610567723-00393</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>10 W 79TH ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610567723-00119</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>634 E 50TH PLACE BLDG</td><td>CHICAGO</td><td>IL</td><td>60615</td><td>Peoples</td><td>0610087723-02119</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8301 S COTTAGE GROVE AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60619</td><td>Peoples</td><td>0610006762-00269</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>2517 E 77TH SMT</td><td>CHICAGO</td><td>IL</td><td>60649</td><td>Peoples</td><td>0610877723-02821</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>5011 S WABASH AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60644</td><td>Peoples</td><td>0600075352-00002</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>6401 S WOODLAWN AVE BSMT</td><td>CHICAGO</td><td>IL</td><td>60629</td><td>Peoples</td><td>0610877723-02772</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7931 S YATES BLDG</td><td>CHICAGO</td><td>IL</td><td>60651</td><td>Peoples</td><td>0610877723-00247</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7750 S PEORIA ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610567723-00777</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>5966 W HURON ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60644</td><td>Peoples</td><td>0610006767-00021</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7055 S SAINT LAWRENCE BLDG</td><td>CHICAGO</td><td>IL</td><td>60637</td><td>Peoples</td><td>0610877723-02984</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>9443 ESCANABA BLDG</td><td>CHICAGO</td><td>IL</td><td>60617</td><td>Peoples</td><td>0610877723-02978</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>3600 W FRANKLIN BLVD SMT</td><td>CHICAGO</td><td>IL</td><td>60624</td><td>Peoples</td><td>0610877723-02813</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>1450 W 81ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610877723-02650</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>2307 S MICHIGAN AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60623</td><td>Peoples</td><td>0610877723-00078</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>13255 S PRAIRIE AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60627</td><td>Peoples</td><td>0610877723-00912</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>6015 S 15TH BLDG</td><td>CHICAGO</td><td>IL</td><td>60615</td><td>Peoples</td><td>0610877723-01108</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>11250 S INDIANA AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60628</td><td>Peoples</td><td>0610877723-02592</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>5019 S SAINT LAWRENCE BLDG</td><td>CHICAGO</td><td>IL</td><td>60615</td><td>Peoples</td><td>0610877723-01109</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8204 S COTTAGE GROVE AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60619</td><td>Peoples</td><td>0613515782-00002</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7055 S PRINCETON AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60621</td><td>Peoples</td><td>0610877723-02985</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7055 S PRINCETON AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60621</td><td>Peoples</td><td>0610877723-00121</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>2419 W 71ST ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60629</td><td>Peoples</td><td>0610877723-02927</td> ...
#         "grounding": [
#           {
#             "box": {
#               "l": 0.14470571279525757,
#               "t": 0.09279540181159973,
#               "r": 0.9624083638191223,
#               "b": 0.8982346057891846
#             },
#             "page": 13
#           }
#         ],
#         "chunk_type": "table",
#         "chunk_id": "da03cc0d-e0f1-46fc-882e-ce4030ef9f8e"
#       },
#       {
#         "text": "Exhibit B: Point of Service Locations  \nMaster Commercial Gas Sales Agreement",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.06233711540699005,
#               "t": 0.6782475709915161,
#               "r": 0.10784877836704254,
#               "b": 0.8976082801818848
#             },
#             "page": 14
#           }
#         ],
#         "chunk_type": "marginalia",
#         "chunk_id": "da8a7e4e-3626-4fdc-a3c8-fa887312d21c"
#       },
#       {
#         "text": "logo: Mansfield, with the tagline \"Every Simplified\" and a stylized \"M\" graphic.\n\nDimensions & Placement :\n  \u2022 Vertical orientation, with text running from bottom to top.\n  \u2022 \"Mansfield\" in bold, large font; \"Every Simplified\" in lighter, smaller font to the right.\n  \u2022 Stylized \"M\" logo at the bottom, occupying a square area.\n\nAnalysis :\n  \u2022 The logo uses a minimalist, grayscale design with a geometric \"M\" to convey a modern, professional brand identity. The tagline \"Every Simplified\" suggests a focus on simplicity and efficiency.",
#         "grounding": [
#           {
#             "box": {
#               "l": 0.060805149376392365,
#               "t": 0.2602521479129791,
#               "r": 0.11308161169290543,
#               "b": 0.37186524271965027
#             },
#             "page": 14
#           }
#         ],
#         "chunk_type": "figure",
#         "chunk_id": "2e697d34-5d6e-43c6-8237-2a52b52e237b"
#       },
#       {
#         "text": "<table><thead><tr><th>Account Name</th><th>Service Address</th><th>City</th><th>State</th><th>Zip</th><th>Utility</th><th>Utility Account #</th><th>Rate Class #</th></tr></thead><tbody><tr><td>Pangea Ventures, LLC</td><td>7906 S HERMITAGE BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0500667672-00016</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7943 S HARVARD BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0500667672-00055</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8101 S DREXEL AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60619</td><td>Peoples</td><td>0601520426-00006</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>1860 S KOMENSKY BLDG</td><td>CHICAGO</td><td>IL</td><td>60623</td><td>Peoples</td><td>0610877223-00514</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>9400 S BISHOP BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610877223-02721</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>1212 69TH ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60637</td><td>Peoples</td><td>0610877223-02571</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7601 S COLES AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60649</td><td>Peoples</td><td>0610877223-02602</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8018 S MARSHFIELD BLDG</td><td>CHICAGO</td><td>IL</td><td>60615</td><td>Peoples</td><td>0610877223-02115</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7101 N WASHTENAW AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60644</td><td>Peoples</td><td>0610877223-02724</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>1145 S INDIAN AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60651</td><td>Peoples</td><td>0610877223-02941</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7145 S INDIANA AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60619</td><td>Peoples</td><td>0608299543-00009</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>10905 S VERNON AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60628</td><td>Peoples</td><td>0610877223-02616</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>1415 W 80TH ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610877223-02969</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8171 S 80TH ST BSMT</td><td>CHICAGO</td><td>IL</td><td>60619</td><td>Peoples</td><td>0610877223-02655</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8212 S DREXEL AVE BSMT</td><td>CHICAGO</td><td>IL</td><td>60637</td><td>Peoples</td><td>0610877223-00001</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8107 S DREXEL AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60619</td><td>Peoples</td><td>0610877223-00096</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>6825 S KINGRY BLDG</td><td>CHICAGO</td><td>IL</td><td>60637</td><td>Peoples</td><td>0611977520-00001</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>5340 W OHIO ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60644</td><td>Peoples</td><td>0500667672-00013</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>7655 S MAYS BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610877223-02577</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>5758 S WABASH AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60637</td><td>Peoples</td><td>0520246-00010</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>1501 E 68TH ST BLDG</td><td>CHICAGO</td><td>IL</td><td>60637</td><td>Peoples</td><td>0610877223-01128</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>8501 S KINGSTON BSMT</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610877223-00736</td><td>Choice</td></tr><tr><td>Pangea Ventures, LLC</td><td>9000 S BISHOP ST AVE BLDG</td><td>CHICAGO</td><td>IL</td><td>60620</td><td>Peoples</td><td>0610877223-02736</td><td>Choice</td></tr><tr><td>Pangea  ...
#         "grounding": [
#           {
#             "box": {
#               "l": 0.1480865180492401,
#               "t": 0.09260150790214539,
#               "r": 0.9667750597000122,
#               "b": 0.8982645273208618
#             },
#             "page": 14
#           }
#         ],
#         "chunk_type": "table",
#         "chunk_id": "b57778b2-5bbd-4da3-b3f2-c23f3828ae85"
#       }
#     ]
#   },
#   "errors": [],
#   "extraction_error": null
# }

# %%
# !mkdir "../landing-ai-sandbox-data/direct_pdf_to_json"

# %%
with open("../landing-ai-sandbox-data/direct_pdf_to_json/document_0_extracted.json", "w") as file:
    json.dump(extracted_info, file, indent=4)

# %% [markdown]
# ----

# %% [markdown]
# ## Multiple files .pdf to .json extraction

# %%
def list_pdf_files(directory_path):
    pdf_files = [file for file in os.listdir(directory_path)
                 if file.lower().endswith(".pdf") and os.path.isfile(os.path.join(directory_path, file))]
    return pdf_files

# %% [markdown]
# Initial attempt

# %%
import random 

headers = {"Authorization": f"Basic {api_key}"}
url = "https://api.va.landing.ai/v1/tools/agentic-document-analysis"

base_pdf_path = "../landing-ai-sandbox-data/input/test_pdfs/"  # Replace with the path to the file
pdf_names = random.sample(list_pdf_files("../landing-ai-sandbox-data/input/test_pdfs/"), 10)  # Replace the file
pdf_path = f"{base_pdf_path}/{pdf_name}"

schema_path = "../schema/"
schema_name = "main_usage_schema.json"  # Replace with the JSON schema
schema_path = f"{schema_path}/{schema_name}"

with open(schema_path, "r") as file:
    schema = json.load(file)

files = [
    ("pdf", (pdf_name, open(pdf_path, "rb"), "application/pdf")) for pdf_name in pdf_names
]

payload = {"fields_schema": json.dumps(schema)}

response = requests.request("POST", url, headers=headers, files=files, data=payload)

output_data = response.json()["data"]
extracted_info = output_data["extracted_schema"]
print(extracted_info)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 25
#      21 payload = {"fields_schema": json.dumps(schema)}
#      23 response = requests.request("POST", url, headers=headers, files=files, data=payload)
# ---> 25 output_data = response.json()["data"]
#      26 extracted_info = output_data["extracted_schema"]
#      27 print(extracted_info)
#
# KeyError: 'data'

# %%
response.json()
# Out:
# {'message': 'Multiple PDF files detected (10). Please provide only one PDF file.'}

# %% [markdown]
# Unable to send 1 request for multiple PDF, need to split up the requests into individual file and send them per file

# %%
headers = {"Authorization": f"Basic {api_key}"}
url = "https://api.va.landing.ai/v1/tools/agentic-document-analysis"

base_pdf_path = "../landing-ai-sandbox-data/input/test_pdfs/"  # Replace with the path to the file
pdf_names = random.sample(list_pdf_files("../landing-ai-sandbox-data/input/test_pdfs/"), 10)  # Replace the file
pdf_path = f"{base_pdf_path}/{pdf_name}"

schema_path = "../schema/"
schema_name = "main_usage_schema.json"  # Replace with the JSON schema
schema_path = f"{schema_path}/{schema_name}"

with open(schema_path, "r") as file:
    schema = json.load(file)

# %%
master_files = [
    ("pdf", (pdf_name, open(f"{base_pdf_path}/{pdf_name}", "rb"), "application/pdf")) for pdf_name in pdf_names
]

# %%
import os

for file in master_files:
    files = [file] # only get one entry per loop

    payload = {"fields_schema": json.dumps(schema)}

    response = requests.request("POST", url, headers=headers, files=files, data=payload)

    output_data = response.json()["data"]
    extracted_info = output_data["extracted_schema"]
    
    file_name = os.path.splitext(file[1][0])[0]
    
    with open(f"../landing-ai-sandbox-data/direct_pdf_to_json/{file_name}_extracted.json", "w") as file:
        json.dump(extracted_info, file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 10
#       6 payload = {"fields_schema": json.dumps(schema)}
#       8 response = requests.request("POST", url, headers=headers, files=files, data=payload)
# ---> 10 output_data = response.json()["data"]
#      11 extracted_info = output_data["extracted_schema"]
#      13 file_name = os.path.splitext(file[1][0])[0]
#
# KeyError: 'data'

# %%
response.json()
# Out:
# {'message': 'Failed to open PDF. Ensure it is a valid PDF file.'}

# %%
def list_exported_json_files(directory_path):
    json_files = [file for file in os.listdir(directory_path)
                 if file.lower().endswith(".json") and os.path.isfile(os.path.join(directory_path, file))]
    return json_files

list_exported_json_files('../landing-ai-sandbox-data/direct_pdf_to_json/')
# Out:
# ['document_734_extracted.json',
#  'document_0_extracted.json',
#  'document_246_extracted.json',
#  'document_760_extracted.json',
#  'document_703_extracted.json',
#  'document_287_extracted.json']

# %%
processed_file = list_exported_json_files('../landing-ai-sandbox-data/direct_pdf_to_json/')
processed_file = [os.path.splitext(file)[0] for file in processed_file]
processed_file = [f'{"_".join(file.split("_")[:2])}.pdf' for file in processed_file]
processed_file
# Out:
# ['document_734.pdf',
#  'document_0.pdf',
#  'document_246.pdf',
#  'document_760.pdf',
#  'document_703.pdf',
#  'document_287.pdf']

# %%
master_files = [
    ("pdf", (pdf_name, open(f"{base_pdf_path}/{pdf_name}", "rb"), "application/pdf")) for pdf_name in list(set(pdf_names) - set(processed_file))
]

# %%
for file in master_files:
    files = [file] # only get one entry per loop

    payload = {"fields_schema": json.dumps(schema)}

    response = requests.request("POST", url, headers=headers, files=files, data=payload)

    output_data = response.json()["data"]
    extracted_info = output_data["extracted_schema"]
    
    file_name = os.path.splitext(file[1][0])[0]
    
    with open(f"../landing-ai-sandbox-data/direct_pdf_to_json/{file_name}_extracted.json", "w") as file:
        json.dump(extracted_info, file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 8
#       4 payload = {"fields_schema": json.dumps(schema)}
#       6 response = requests.request("POST", url, headers=headers, files=files, data=payload)
# ----> 8 output_data = response.json()["data"]
#       9 extracted_info = output_data["extracted_schema"]
#      11 file_name = os.path.splitext(file[1][0])[0]
#
# KeyError: 'data'

# %%
response.json()
# Out:
# {'message': 'Failed to open PDF. Ensure it is a valid PDF file.'}

# %% [markdown]
# ---

# %% [markdown]
# ## Cleanup

# %%
# !rm -rf '../landing-ai-sandbox-data/input/test_pdfs'
