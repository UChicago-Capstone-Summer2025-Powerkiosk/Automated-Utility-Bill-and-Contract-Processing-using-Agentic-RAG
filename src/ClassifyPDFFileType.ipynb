# %% [markdown]
# Install dependencies

# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Using cached pymupdf-1.25.5-cp39-abi3-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Using cached pymupdf-1.25.5-cp39-abi3-macosx_11_0_arm64.whl (18.6 MB)
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.25.5

# %%
import os
import fitz  # PyMuPDF
import csv

# %%
def SafeExtractText(file_path):
    """
    Safely extract text from a PDF using PyMuPDF (fitz).
    Returns None if the file is invalid, empty, or unreadable.
    """
    try:
        if not os.path.exists(file_path):
            print(f"File not found: {file_path}")
            return None, "File not found"
        if os.path.getsize(file_path) == 0:
            print(f"Empty file: {file_path}")
            return None, "Empty file"

        doc = fitz.open(file_path)
        text = " ".join(page.get_text() for page in doc)
        doc.close()

        if not text.strip():
            print(f"No text extracted: {file_path}")
            return None, "No text extracted"

        return text.strip(), None

    except fitz.FileDataError as e:  # Specific catch for PDF corruption-related issues
        print(f"Corrupted PDF or file data issue: {file_path}")
        return None, f"Corrupted PDF: {str(e)}"

    except fitz.PdfError as e:  # More general catch for PDF-specific errors
        print(f"PDF error in {file_path}: {str(e)}")
        return None, f"PDF error: {str(e)}"

    except Exception as e:
        print(f"Unexpected error in {file_path}: {e}")
        return None, f"Unexpected error: {e}"

def LoadValidDocuments(folder_path, log_file="skipped_files.csv"):
    """
    Load and extract text from all valid PDF files in the given folder.
    Logs failed files with reasons to a .csv file.
    Returns a list of texts and corresponding filenames.
    """
    documents = []
    filenames = []
    skipped = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"):
            full_path = os.path.join(folder_path, filename)
            print(f"Processing: {filename}")

            text, error_reason = SafeExtractText(full_path)

            if text:
                documents.append(text)
                filenames.append(filename)
            else:
                print(f"Skipping: {filename} ({error_reason})")
                skipped.append([filename, error_reason])

    # Write skipped files with reasons to .csv
    if skipped:
        with open(log_file, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["filename", "error_reason"])
            writer.writerows(skipped)
        print(f"Skipped files logged in: {log_file}")

    print(f"Successfully loaded {len(documents)} documents.\n")
    return documents, filenames

# === Example Usage ===
if __name__ == "__main__":
    folder_path = "../data/raw_data"  # Adjust to your folder path
    documents, filenames = LoadValidDocuments(folder_path, log_file="skipped_files.csv")

    # Show sample output of loaded documents
    for i, (name, text) in enumerate(zip(filenames, documents[:3])):
        print(f"--- Document {i+1}: {name} ---\n{text[:500]}...\n")
# Out:
# Processing: document_459.pdf
# No text extracted: ../data/raw_data/document_459.pdf
# Skipping: document_459.pdf (No text extracted)
# Processing: document_317.pdf
# Processing: document_471.pdf
# Processing: document_465.pdf
# Processing: document_303.pdf
# Processing: document_854.pdf
# Processing: document_1105.pdf
# Processing: document_840.pdf
# Processing: document_1111.pdf
# No text extracted: ../data/raw_data/document_1111.pdf
# Skipping: document_1111.pdf (No text extracted)
# Processing: document_698.pdf
# No text extracted: ../data/raw_data/document_698.pdf
# Skipping: document_698.pdf (No text extracted)
# Processing: document_868.pdf
# No text extracted: ../data/raw_data/document_868.pdf
# Skipping: document_868.pdf (No text extracted)
# Processing: document_1139.pdf
# Processing: document_897.pdf
# No text extracted: ../data/raw_data/document_897.pdf
# Skipping: document_897.pdf (No text extracted)
# Processing: document_129.pdf
# No text extracted: ../data/raw_data/document_129.pdf
# Skipping: document_129.pdf (No text extracted)
# Processing: document_883.pdf
# No text extracted: ../data/raw_data/document_883.pdf
# Skipping: document_883.pdf (No text extracted)
# Processing: document_673.pdf
# Processing: document_115.pdf
# No text extracted: ../data/raw_data/document_115.pdf
# Skipping: document_115.pdf (No text extracted)
# Processing: document_101.pdf
# Processing: document_667.pdf
# Processing: document_1071.pdf
# No text extracted: ../data/raw_data/document_1071.pdf
# Skipping: document_1071.pdf (No text extracted)
# Processing: document_920.pdf
# Processing: document_1065.pdf
# Processing: document_934.pdf
# No text extracted: ../data/raw_data/document_934.pdf
# Skipping: document_934.pdf (No text extracted)
# Processing: document_1059.pdf
# No text extracted: ../data/raw_data/document_1059.pdf
# Skipping: document_1059.pdf (No text extracted)
# Processing: document_908.pdf
# No text extracted: ../data/raw_data/document_908.pdf
# Skipping: document_908.pdf (No text extracted)
# Processing: document_707.pdf
# Processing: document_713.pdf
# No text extracted: ../data/raw_data/document_713.pdf
# Skipping: document_713.pdf (No text extracted)
# Processing: document_288.pdf
# Processing: document_12.pdf
# No text extracted: ../data/raw_data/document_12.pdf
# Skipping: document_12.pdf (No text extracted)
# Processing: document_539.pdf
# Processing: document_263.pdf
# Processing: document_505.pdf
# Processing: document_511.pdf
# Processing: document_277.pdf
# Processing: document_510.pdf
# Processing: document_276.pdf
# Processing: document_262.pdf
# Processing: document_504.pdf
# Processing: document_538.pdf
# No text extracted: ../data/raw_data/document_538.pdf
# Skipping: document_538.pdf (No text extracted)
# Processing: document_13.pdf
# No text extracted: ../data/raw_data/document_13.pdf
# Skipping: document_13.pdf (No text extracted)
# Processing: document_289.pdf
# Processing: document_712.pdf
# Processing: document_706.pdf
# No text extracted: ../data/raw_data/document_706.pdf
# Skipping: document_706.pdf (No text extracted)
# Processing: document_909.pdf
# No text extracted: ../data/raw_data/document_909.pdf
# Skipping: document_909.pdf (No text extracted)
# Processing: document_1058.pdf
# Processing: document_935.pdf
# No text extracted: ../data/raw_data/document_935.pdf
# Skipping: document_935.pdf (No text extracted)
# Processing: document_1064.pdf
# Processing: document_921.pdf
# Processing: document_1070.pdf
# Processing: document_100.pdf
# Processing: document_666.pdf
# Processing: document_672.pdf
# Processing: document_114.pdf
# Processing: document_882.pdf
# Processing: document_896.pdf
# Processing: document_128.pdf
# No text extracted: ../data/raw_data/document_128.pdf
# Skipping: document_128.pdf (No text extracted)
# Processing: document_1138.pdf
# Processing: document_869.pdf
# No text extracted: ../data/raw_data/document_869.pdf
# Skipping: document_869.pdf (No text extracted)
# Processing: document_1110.pdf
# No text extracted: ../data/raw_data/document_1110.pdf
# Skipping: document_1110.pdf (No text extracted)
# Processing: document_699.pdf
# No text extracted: ../data/raw_data/document_699.pdf
# Skipping: document_699.pdf (No text extracted)
# Processing: document_841.pdf
# Processing: document_1104.pdf
# Processing: document_855.pdf
# Processing: document_464.pdf
# Processing: document_302.pdf
# Processing: document_316.pdf
# Processing: document_470.pdf
# Processing: document_458.pdf
# No text extracted: ../data/raw_data/document_458.pdf
# Skipping: document_458.pdf (No text extracted)
# Processing: document_499.pdf
# Processing: document_328.pdf
# Processing: document_300.pdf
# Processing: document_466.pdf
# Processing: document_472.pdf
# Processing: document_314.pdf
# Processing: document_843.pdf
# Processing: document_1112.pdf
# No text extracted: ../data/raw_data/document_1112.pdf
# Skipping: document_1112.pdf (No text extracted)
# Processing: document_857.pdf
# Processing: document_1106.pdf
# Processing: document_658.pdf
# Processing: document_880.pdf
# No text extracted: ../data/raw_data/document_880.pdf
# Skipping: document_880.pdf (No text extracted)
# Processing: document_894.pdf
# No text extracted: ../data/raw_data/document_894.pdf
# Skipping: document_894.pdf (No text extracted)
# Processing: document_664.pdf
# Processing: document_102.pdf
# Processing: document_116.pdf
# Processing: document_670.pdf
# Processing: document_1066.pdf
# Processing: document_937.pdf
# No text extracted: ../data/raw_data/document_937.pdf
# Skipping: document_937.pdf (No text extracted)
# Processing: document_1072.pdf
# Processing: document_923.pdf
# Processing: document_738.pdf
# Processing: document_710.pdf
# No text extracted: ../data/raw_data/document_710.pdf
# Skipping: document_710.pdf (No text extracted)
# Processing: document_1099.pdf
# Processing: document_704.pdf
# No text extracted: ../data/raw_data/document_704.pdf
# Skipping: document_704.pdf (No text extracted)
# Processing: document_39.pdf
# Processing: document_11.pdf
# No text extracted: ../data/raw_data/document_11.pdf
# Skipping: document_11.pdf (No text extracted)
# Processing: document_248.pdf
# Processing: document_274.pdf
# Processing: document_512.pdf
# Processing: document_506.pdf
# Processing: document_260.pdf
# Processing: document_507.pdf
# Processing: document_261.pdf
# Processing: document_275.pdf
# Processing: document_513.pdf
# Processing: document_249.pdf
# Processing: document_10.pdf
# No text extracted: ../data/raw_data/document_10.pdf
# Skipping: document_10.pdf (No text extracted)
# Processing: document_38.pdf
# Processing: document_705.pdf
# Corrupted PDF or file data issue: ../data/raw_data/document_705.pdf
# Skipping: document_705.pdf (Corrupted PDF: Failed to open file '../data/raw_data/document_705.pdf'.)
# Processing: document_711.pdf
# No text extracted: ../data/raw_data/document_711.pdf
# Skipping: document_711.pdf (No text extracted)
# Processing: document_1098.pdf
# Processing: document_739.pdf
# Corrupted PDF or file data issue: ../data/raw_data/document_739.pdf
# Skipping: document_739.pdf (Corrupted PDF: Failed to open file '../data/raw_data/document_739.pdf'.)
# Processing: document_922.pdf
# No text extracted: ../data/raw_data/document_922.pdf
# Skipping: document_922.pdf (No text extracted)
# Processing: document_1073.pdf
# No text extracted: ../data/raw_data/document_1073.pdf
# Skipping: document_1073.pdf (No text extracted)
# Processing: document_936.pdf
# No text extracted: ../data/raw_data/document_936.pdf
# Skipping: document_936.pdf (No text extracted)
# Processing: document_1067.pdf
# Processing: document_117.pdf
# No text extracted: ../data/raw_data/document_117.pdf
# Skipping: document_117.pdf (No text extracted)
# Processing: document_671.pdf
# Processing: document_665.pdf
# Processing: document_103.pdf
# Processing: document_895.pdf
# No text extracted: ../data/raw_data/document_895.pdf
# Skipping: document_895.pdf (No text extracted)
# Processing: document_881.pdf
# No text extracted: ../data/raw_data/document_881.pdf
# Skipping: document_881.pdf (No text extracted)
# Processing: document_659.pdf
# No text extracted: ../data/raw_data/document_659.pdf
# Skipping: document_659.pdf (No text extracted)
# Processing: document_1107.pdf
# Processing: document_856.pdf
# Processing: document_1113.pdf
# No text extracted: ../data/raw_data/document_1113.pdf
# Skipping: document_1113.pdf (No text extracted)
# Processing: document_842.pdf
# Processing: document_473.pdf
# Processing: document_315.pdf
# Processing: document_301.pdf
# Processing: document_467.pdf
# Processing: document_329.pdf
# Processing: document_498.pdf
# No text extracted: ../data/raw_data/document_498.pdf
# Skipping: document_498.pdf (No text extracted)
# Processing: document_488.pdf
# Processing: document_463.pdf
# Processing: document_305.pdf
# Processing: document_311.pdf
# Processing: document_477.pdf
# Processing: document_339.pdf
# No text extracted: ../data/raw_data/document_339.pdf
# Skipping: document_339.pdf (No text extracted)
# Processing: document_846.pdf
# Processing: document_1117.pdf
# No text extracted: ../data/raw_data/document_1117.pdf
# Skipping: document_1117.pdf (No text extracted)
# Processing: document_852.pdf
# Processing: document_1103.pdf
# Processing: document_107.pdf
# Processing: document_661.pdf
# Processing: document_675.pdf
# Processing: document_113.pdf
# No text extracted: ../data/raw_data/document_113.pdf
# Skipping: document_113.pdf (No text extracted)
# Processing: document_885.pdf
# No text extracted: ../data/raw_data/document_885.pdf
# Skipping: document_885.pdf (No text extracted)
# Processing: document_649.pdf
# Processing: document_891.pdf
# No text extracted: ../data/raw_data/document_891.pdf
# Skipping: document_891.pdf (No text extracted)
# Processing: document_1063.pdf
# Processing: document_932.pdf
# No text extracted: ../data/raw_data/document_932.pdf
# Skipping: document_932.pdf (No text extracted)
# Processing: document_1077.pdf
# Processing: document_926.pdf
# No text extracted: ../data/raw_data/document_926.pdf
# Skipping: document_926.pdf (No text extracted)
# Processing: document_715.pdf
# No text extracted: ../data/raw_data/document_715.pdf
# Skipping: document_715.pdf (No text extracted)
# Processing: document_701.pdf
# No text extracted: ../data/raw_data/document_701.pdf
# Skipping: document_701.pdf (No text extracted)
# Processing: document_1088.pdf
# Processing: document_729.pdf
# Processing: document_14.pdf
# No text extracted: ../data/raw_data/document_14.pdf
# Skipping: document_14.pdf (No text extracted)
# Processing: document_28.pdf
# Processing: document_517.pdf
# Processing: document_271.pdf
# Processing: document_265.pdf
# Processing: document_503.pdf
# Processing: document_259.pdf
# Processing: document_258.pdf
# Processing: document_264.pdf
# Processing: document_502.pdf
# Processing: document_516.pdf
# Processing: document_270.pdf
# Processing: document_29.pdf
# No text extracted: ../data/raw_data/document_29.pdf
# Skipping: document_29.pdf (No text extracted)
# Processing: document_15.pdf
# No text extracted: ../data/raw_data/document_15.pdf
# Skipping: document_15.pdf (No text extracted)
# Processing: document_728.pdf
# No text extracted: ../data/raw_data/document_728.pdf
# Skipping: document_728.pdf (No text extracted)
# Processing: document_700.pdf
# No text extracted: ../data/raw_data/document_700.pdf
# Skipping: document_700.pdf (No text extracted)
# Processing: document_1089.pdf
# Processing: document_714.pdf
# Processing: document_927.pdf
# No text extracted: ../data/raw_data/document_927.pdf
# Skipping: document_927.pdf (No text extracted)
# Processing: document_1076.pdf
# No text extracted: ../data/raw_data/document_1076.pdf
# Skipping: document_1076.pdf (No text extracted)
# Processing: document_933.pdf
# No text extracted: ../data/raw_data/document_933.pdf
# Skipping: document_933.pdf (No text extracted)
# Processing: document_1062.pdf
# No text extracted: ../data/raw_data/document_1062.pdf
# Skipping: document_1062.pdf (No text extracted)
# Processing: document_890.pdf
# Processing: document_648.pdf
# Processing: document_884.pdf
# No text extracted: ../data/raw_data/document_884.pdf
# Skipping: document_884.pdf (No text extracted)
# Processing: document_674.pdf
# Processing: document_112.pdf
# Processing: document_106.pdf
# Corrupted PDF or file data issue: ../data/raw_data/document_106.pdf
# Skipping: document_106.pdf (Corrupted PDF: Failed to open file '../data/raw_data/document_106.pdf'.)
# Processing: document_660.pdf
# No text extracted: ../data/raw_data/document_660.pdf
# Skipping: document_660.pdf (No text extracted)
# Processing: document_1102.pdf
# Processing: document_853.pdf
# Processing: document_1116.pdf
# No text extracted: ../data/raw_data/document_1116.pdf
# Skipping: document_1116.pdf (No text extracted)
# Processing: document_847.pdf
# Processing: document_338.pdf
# Processing: document_310.pdf
# Processing: document_476.pdf
# Processing: document_462.pdf
# No text extracted: ../data/raw_data/document_462.pdf
# Skipping: document_462.pdf (No text extracted)
# Processing: document_304.pdf
# Processing: document_489.pdf
# Processing: document_474.pdf
# Processing: document_312.pdf
# Processing: document_306.pdf
# Processing: document_460.pdf
# No text extracted: ../data/raw_data/document_460.pdf
# Skipping: document_460.pdf (No text extracted)
# Processing: document_448.pdf
# No text extracted: ../data/raw_data/document_448.pdf
# Skipping: document_448.pdf (No text extracted)
# Processing: document_879.pdf
# No text extracted: ../data/raw_data/document_879.pdf
# Skipping: document_879.pdf (No text extracted)
# Processing: document_1128.pdf
# No text extracted: ../data/raw_data/document_1128.pdf
# Skipping: document_1128.pdf (No text extracted)
# Processing: document_851.pdf
# Processing: document_1100.pdf
# Processing: document_689.pdf
# Processing: document_845.pdf
# Processing: document_1114.pdf
# Processing: document_110.pdf
# Processing: document_676.pdf
# Processing: document_662.pdf
# Processing: document_104.pdf
# Processing: document_892.pdf
# Processing: document_886.pdf
# Processing: document_138.pdf
# Processing: document_1048.pdf
# No text extracted: ../data/raw_data/document_1048.pdf
# Skipping: document_1048.pdf (No text extracted)
# Processing: document_919.pdf
# No text extracted: ../data/raw_data/document_919.pdf
# Skipping: document_919.pdf (No text extracted)
# Processing: document_1074.pdf
# No text extracted: ../data/raw_data/document_1074.pdf
# Skipping: document_1074.pdf (No text extracted)
# Processing: document_925.pdf
# No text extracted: ../data/raw_data/document_925.pdf
# Skipping: document_925.pdf (No text extracted)
# Processing: document_1060.pdf
# No text extracted: ../data/raw_data/document_1060.pdf
# Skipping: document_1060.pdf (No text extracted)
# Processing: document_931.pdf
# No text extracted: ../data/raw_data/document_931.pdf
# Skipping: document_931.pdf (No text extracted)
# Processing: document_702.pdf
# No text extracted: ../data/raw_data/document_702.pdf
# Skipping: document_702.pdf (No text extracted)
# Processing: document_716.pdf
# No text extracted: ../data/raw_data/document_716.pdf
# Skipping: document_716.pdf (No text extracted)
# Processing: document_17.pdf
# Processing: document_299.pdf
# Processing: document_500.pdf
# No text extracted: ../data/raw_data/document_500.pdf
# Skipping: document_500.pdf (No text extracted)
# Processing: document_266.pdf
# Processing: document_272.pdf
# Processing: document_514.pdf
# Processing: document_528.pdf
# No text extracted: ../data/raw_data/document_528.pdf
# Skipping: document_528.pdf (No text extracted)
# Processing: document_529.pdf
# Processing: document_273.pdf
# Processing: document_515.pdf
# Processing: document_501.pdf
# No text extracted: ../data/raw_data/document_501.pdf
# Skipping: document_501.pdf (No text extracted)
# Processing: document_267.pdf
# Processing: document_298.pdf
# Processing: document_16.pdf
# No text extracted: ../data/raw_data/document_16.pdf
# Skipping: document_16.pdf (No text extracted)
# Processing: document_717.pdf
# No text extracted: ../data/raw_data/document_717.pdf
# Skipping: document_717.pdf (No text extracted)
# Processing: document_703.pdf
# Processing: document_930.pdf
# No text extracted: ../data/raw_data/document_930.pdf
# Skipping: document_930.pdf (No text extracted)
# Processing: document_1061.pdf
# Processing: document_924.pdf
# No text extracted: ../data/raw_data/document_924.pdf
# Skipping: document_924.pdf (No text extracted)
# Processing: document_1075.pdf
# Processing: document_918.pdf
# Processing: document_1049.pdf
# No text extracted: ../data/raw_data/document_1049.pdf
# Skipping: document_1049.pdf (No text extracted)
# Processing: document_887.pdf
# Processing: document_139.pdf
# Processing: document_893.pdf
# No text extracted: ../data/raw_data/document_893.pdf
# Skipping: document_893.pdf (No text extracted)
# Processing: document_663.pdf
# No text extracted: ../data/raw_data/document_663.pdf
# Skipping: document_663.pdf (No text extracted)
# Processing: document_105.pdf
# Processing: document_111.pdf
# No text extracted: ../data/raw_data/document_111.pdf
# Skipping: document_111.pdf (No text extracted)
# Processing: document_677.pdf
# Processing: document_1115.pdf
# Corrupted PDF or file data issue: ../data/raw_data/document_1115.pdf
# Skipping: document_1115.pdf (Corrupted PDF: Failed to open file '../data/raw_data/document_1115.pdf'.)
# Processing: document_844.pdf
# Processing: document_1101.pdf
# Processing: document_688.pdf
# Processing: document_850.pdf
# Processing: document_1129.pdf
# Processing: document_878.pdf
# Processing: document_449.pdf
# Processing: document_307.pdf
# Processing: document_461.pdf
# No text extracted: ../data/raw_data/document_461.pdf
# Skipping: document_461.pdf (No text extracted)
# Processing: document_475.pdf
# Processing: document_313.pdf
# Processing: document_348.pdf
# Processing: document_412.pdf
# Processing: document_374.pdf
# Processing: document_360.pdf
# Processing: document_406.pdf
# Processing: document_189.pdf
# No text extracted: ../data/raw_data/document_189.pdf
# Skipping: document_189.pdf (No text extracted)
# Processing: document_837.pdf
# Processing: document_1166.pdf
# Processing: document_823.pdf
# Processing: document_638.pdf
# Processing: document_176.pdf
# No text extracted: ../data/raw_data/document_176.pdf
# Skipping: document_176.pdf (No text extracted)
# Processing: document_610.pdf
# Processing: document_604.pdf
# Processing: document_0.pdf
# No text extracted: ../data/raw_data/document_0.pdf
# Skipping: document_0.pdf (No text extracted)
# Processing: document_162.pdf
# No text extracted: ../data/raw_data/document_162.pdf
# Skipping: document_162.pdf (No text extracted)
# Processing: document_1012.pdf
# Processing: document_943.pdf
# No text extracted: ../data/raw_data/document_943.pdf
# Skipping: document_943.pdf (No text extracted)
# Processing: document_1006.pdf
# Processing: document_957.pdf
# Processing: document_980.pdf
# No text extracted: ../data/raw_data/document_980.pdf
# Skipping: document_980.pdf (No text extracted)
# Processing: document_758.pdf
# No text extracted: ../data/raw_data/document_758.pdf
# Skipping: document_758.pdf (No text extracted)
# Processing: document_994.pdf
# No text extracted: ../data/raw_data/document_994.pdf
# Skipping: document_994.pdf (No text extracted)
# Processing: document_764.pdf
# Processing: document_770.pdf
# No text extracted: ../data/raw_data/document_770.pdf
# Skipping: document_770.pdf (No text extracted)
# Processing: document_599.pdf
# Processing: document_59.pdf
# Processing: document_65.pdf
# No text extracted: ../data/raw_data/document_65.pdf
# Skipping: document_65.pdf (No text extracted)
# Processing: document_71.pdf
# No text extracted: ../data/raw_data/document_71.pdf
# Skipping: document_71.pdf (No text extracted)
# Processing: document_228.pdf
# No text extracted: ../data/raw_data/document_228.pdf
# Skipping: document_228.pdf (No text extracted)
# Processing: document_566.pdf
# Processing: document_200.pdf
# Processing: document_214.pdf
# Processing: document_572.pdf
# No text extracted: ../data/raw_data/document_572.pdf
# Skipping: document_572.pdf (No text extracted)
# Processing: document_215.pdf
# Processing: document_573.pdf
# Processing: document_567.pdf
# Processing: document_201.pdf
# Processing: document_229.pdf
# No text extracted: ../data/raw_data/document_229.pdf
# Skipping: document_229.pdf (No text extracted)
# Processing: document_70.pdf
# No text extracted: ../data/raw_data/document_70.pdf
# Skipping: document_70.pdf (No text extracted)
# Processing: document_64.pdf
# Processing: document_58.pdf
# No text extracted: ../data/raw_data/document_58.pdf
# Skipping: document_58.pdf (No text extracted)
# Processing: document_598.pdf
# No text extracted: ../data/raw_data/document_598.pdf
# Skipping: document_598.pdf (No text extracted)
# Processing: document_771.pdf
# No text extracted: ../data/raw_data/document_771.pdf
# Skipping: document_771.pdf (No text extracted)
# Processing: document_765.pdf
# No text extracted: ../data/raw_data/document_765.pdf
# Skipping: document_765.pdf (No text extracted)
# Processing: document_995.pdf
# No text extracted: ../data/raw_data/document_995.pdf
# Skipping: document_995.pdf (No text extracted)
# Processing: document_759.pdf
# No text extracted: ../data/raw_data/document_759.pdf
# Skipping: document_759.pdf (No text extracted)
# Processing: document_981.pdf
# Processing: document_956.pdf
# No text extracted: ../data/raw_data/document_956.pdf
# Skipping: document_956.pdf (No text extracted)
# Processing: document_1007.pdf
# No text extracted: ../data/raw_data/document_1007.pdf
# Skipping: document_1007.pdf (No text extracted)
# Processing: document_942.pdf
# No text extracted: ../data/raw_data/document_942.pdf
# Skipping: document_942.pdf (No text extracted)
# Processing: document_1013.pdf
# No text extracted: ../data/raw_data/document_1013.pdf
# Skipping: document_1013.pdf (No text extracted)
# Processing: document_1.pdf
# No text extracted: ../data/raw_data/document_1.pdf
# Skipping: document_1.pdf (No text extracted)
# Processing: document_605.pdf
# Processing: document_163.pdf
# No text extracted: ../data/raw_data/document_163.pdf
# Skipping: document_163.pdf (No text extracted)
# Processing: document_177.pdf
# No text extracted: ../data/raw_data/document_177.pdf
# Skipping: document_177.pdf (No text extracted)
# Processing: document_611.pdf
# Processing: document_639.pdf
# No text extracted: ../data/raw_data/document_639.pdf
# Skipping: document_639.pdf (No text extracted)
# Processing: document_822.pdf
# Processing: document_188.pdf
# Processing: document_1167.pdf
# No text extracted: ../data/raw_data/document_1167.pdf
# Skipping: document_1167.pdf (No text extracted)
# Processing: document_836.pdf
# Processing: document_361.pdf
# Processing: document_407.pdf
# Processing: document_413.pdf
# Processing: document_375.pdf
# No text extracted: ../data/raw_data/document_375.pdf
# Skipping: document_375.pdf (No text extracted)
# Processing: document_349.pdf
# Processing: document_388.pdf
# Processing: document_439.pdf
# Processing: document_405.pdf
# Processing: document_363.pdf
# Processing: document_377.pdf
# Processing: document_411.pdf
# Processing: document_820.pdf
# No text extracted: ../data/raw_data/document_820.pdf
# Skipping: document_820.pdf (No text extracted)
# Processing: document_834.pdf
# Processing: document_1165.pdf
# No text extracted: ../data/raw_data/document_1165.pdf
# Skipping: document_1165.pdf (No text extracted)
# Processing: document_808.pdf
# Processing: document_1159.pdf
# No text extracted: ../data/raw_data/document_1159.pdf
# Skipping: document_1159.pdf (No text extracted)
# Processing: document_149.pdf
# Processing: document_161.pdf
# No text extracted: ../data/raw_data/document_161.pdf
# Skipping: document_161.pdf (No text extracted)
# Processing: document_607.pdf
# Processing: document_3.pdf
# No text extracted: ../data/raw_data/document_3.pdf
# Skipping: document_3.pdf (No text extracted)
# Processing: document_613.pdf
# Processing: document_175.pdf
# No text extracted: ../data/raw_data/document_175.pdf
# Skipping: document_175.pdf (No text extracted)
# Processing: document_1005.pdf
# No text extracted: ../data/raw_data/document_1005.pdf
# Skipping: document_1005.pdf (No text extracted)
# Processing: document_954.pdf
# Processing: document_1011.pdf
# Processing: document_798.pdf
# No text extracted: ../data/raw_data/document_798.pdf
# Skipping: document_798.pdf (No text extracted)
# Processing: document_940.pdf
# No text extracted: ../data/raw_data/document_940.pdf
# Skipping: document_940.pdf (No text extracted)
# Processing: document_1039.pdf
# No text extracted: ../data/raw_data/document_1039.pdf
# Skipping: document_1039.pdf (No text extracted)
# Processing: document_968.pdf
# Processing: document_997.pdf
# No text extracted: ../data/raw_data/document_997.pdf
# Skipping: document_997.pdf (No text extracted)
# Processing: document_983.pdf
# Processing: document_773.pdf
# No text extracted: ../data/raw_data/document_773.pdf
# Skipping: document_773.pdf (No text extracted)
# Processing: document_767.pdf
# No text extracted: ../data/raw_data/document_767.pdf
# Skipping: document_767.pdf (No text extracted)
# Processing: document_72.pdf
# No text extracted: ../data/raw_data/document_72.pdf
# Skipping: document_72.pdf (No text extracted)
# Processing: document_66.pdf
# No text extracted: ../data/raw_data/document_66.pdf
# Skipping: document_66.pdf (No text extracted)
# Processing: document_559.pdf
# No text extracted: ../data/raw_data/document_559.pdf
# Skipping: document_559.pdf (No text extracted)
# Processing: document_99.pdf
# Processing: document_571.pdf
# No text extracted: ../data/raw_data/document_571.pdf
# Skipping: document_571.pdf (No text extracted)
# Processing: document_217.pdf
# Processing: document_203.pdf
# No text extracted: ../data/raw_data/document_203.pdf
# Skipping: document_203.pdf (No text extracted)
# Processing: document_565.pdf
# Processing: document_202.pdf
# Processing: document_564.pdf
# Processing: document_570.pdf
# No text extracted: ../data/raw_data/document_570.pdf
# Skipping: document_570.pdf (No text extracted)
# Processing: document_216.pdf
# Processing: document_98.pdf
# Processing: document_558.pdf
# No text extracted: ../data/raw_data/document_558.pdf
# Skipping: document_558.pdf (No text extracted)
# Processing: document_67.pdf
# No text extracted: ../data/raw_data/document_67.pdf
# Skipping: document_67.pdf (No text extracted)
# Processing: document_73.pdf
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# ...
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (951 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (952 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (933 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (934 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (953 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (935 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# MuPDF error: format error: cannot find object in xref (936 0 R)
#
# Processing: document_246.pdf
# Processing: document_291.pdf
# Processing: document_37.pdf
# Processing: document_23.pdf
# Processing: document_285.pdf
# Processing: document_1083.pdf
# No text extracted: ../data/raw_data/document_1083.pdf
# Skipping: document_1083.pdf (No text extracted)
# Processing: document_1097.pdf
# Processing: document_736.pdf
# Processing: document_722.pdf
# No text extracted: ../data/raw_data/document_722.pdf
# Skipping: document_722.pdf (No text extracted)
# Processing: document_911.pdf
# No text extracted: ../data/raw_data/document_911.pdf
# Skipping: document_911.pdf (No text extracted)
# Processing: document_1040.pdf
# No text extracted: ../data/raw_data/document_1040.pdf
# Skipping: document_1040.pdf (No text extracted)
# Processing: document_905.pdf
# No text extracted: ../data/raw_data/document_905.pdf
# Skipping: document_905.pdf (No text extracted)
# Processing: document_1054.pdf
# Processing: document_939.pdf
# No text extracted: ../data/raw_data/document_939.pdf
# Skipping: document_939.pdf (No text extracted)
# Processing: document_1068.pdf
# Processing: document_118.pdf
# Processing: document_642.pdf
# Processing: document_124.pdf
# No text extracted: ../data/raw_data/document_124.pdf
# Skipping: document_124.pdf (No text extracted)
# Processing: document_130.pdf
# No text extracted: ../data/raw_data/document_130.pdf
# Skipping: document_130.pdf (No text extracted)
# Processing: document_656.pdf
# Processing: document_1134.pdf
# No text extracted: ../data/raw_data/document_1134.pdf
# Skipping: document_1134.pdf (No text extracted)
# Processing: document_865.pdf
# No text extracted: ../data/raw_data/document_865.pdf
# Skipping: document_865.pdf (No text extracted)
# Processing: document_1120.pdf
# No text extracted: ../data/raw_data/document_1120.pdf
# Skipping: document_1120.pdf (No text extracted)
# Processing: document_871.pdf
# Processing: document_1108.pdf
# Processing: document_681.pdf
# Processing: document_859.pdf
# Processing: document_695.pdf
# No text extracted: ../data/raw_data/document_695.pdf
# Skipping: document_695.pdf (No text extracted)
# Processing: document_468.pdf
# Processing: document_326.pdf
# Processing: document_440.pdf
# Processing: document_454.pdf
# Processing: document_332.pdf
# No text extracted: ../data/raw_data/document_332.pdf
# Skipping: document_332.pdf (No text extracted)
# Processing: document_483.pdf
# Processing: document_497.pdf
# Skipped files logged in: skipped_files.csv
# Successfully loaded 691 documents.
#
# --- Document 1: document_317.pdf ---
# 1 M
# J
# EVERSSURCE
# Total Amount Due
# by 02/16/24
# $2,222.16
# Account Number:
# Statement Date:
# Service Provided To:
# TOWN OF BERLIN
# 5160 051 3022
# 12/18/23
# j Amount Due 0n12/11/23
# j Last Payment Received On 11/15/23
# I Balance Forward
# E Total Current Charges
# $2,376.90
# -$1,162.11
# ■^,007.37
# Electric Usage History - Kilowatt Hours (kwh)
# Current Charges for Electricity
# Supply
# $422.39
# Delivery
# $584.98
# kWWOay
# 350-1
# 300-
# Costof electricity from NEXTERA
# ENERGY SERVICES CONN
# Cost to deliver electricity
# from Everso...
#
# --- Document 2: document_471.pdf ---
# Account Number:
# Amount Enclosed
# Please make your check payable to Eversource and consider adding $1 for Good Neighbor.
# WM_230404PROD.TXT
# You may be subject to a 1.02% late payment charge if
# the "Total Amount Due" is not received by 04/29/23
# Eversource
# PO Box 56005
# Boston, MA 02205-6005
# 5441420701937 0011569675 0000120463
# Visit Eversource.com to make your payment today. If mailing payment, please allow up to 5 business days to post.
# Remit Payment To: Eversource, PO Box 56005, Boston, MA 02205-600...
#
# --- Document 3: document_465.pdf ---
# Account Number:
# Amount Enclosed
# Please make your check payable to Eversource and consider adding $1 for Good Neighbor.
# WM_230413PROD.TXT
# You may be subject to a 1.02% late payment charge if
# the "Total Amount Due" is not received by 05/08/23
# Eversource
# PO Box 56005
# Boston, MA 02205-6005
# 5454840207241 0000325257 0000325257
# Visit Eversource.com to make your payment today. If mailing payment, please allow up to 5 business days to post.
# Remit Payment To: Eversource, PO Box 56005, Boston, MA 02205-600...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
import joblib  # to save/load the model

# %%
# Extract text using fitz
def SafeExtractText(file_path):
    try:
        if not os.path.exists(file_path):
            return None, "File not found"
        if os.path.getsize(file_path) == 0:
            return None, "Empty file"

        doc = fitz.open(file_path)
        text = " ".join(page.get_text() for page in doc)
        doc.close()

        if not text.strip():
            return None, "No text extracted"

        return text.strip(), None

    except fitz.FileDataError as e:
        return None, f"FileDataError: {str(e)}"

    except RuntimeError as e:
        return None, f"RuntimeError: {str(e)}"

    except Exception as e:
        return None, f"Unexpected error: {e}"

# Load and filter documents
def LoadValidDocuments(folder_path, log_file="skipped_files.csv"):
    documents, filenames, skipped = [], [], []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"):
            full_path = os.path.join(folder_path, filename)
            print(f"Processing: {filename}")

            text, error = SafeExtractText(full_path)

            if text:
                documents.append(text)
                filenames.append(filename)
            else:
                print(f"Skipping: {filename} ({error})")
                skipped.append([filename, error])

    if skipped:
        with open(log_file, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["filename", "error_reason"])
            writer.writerows(skipped)
        print(f"Logged skipped files to {log_file}")

    print(f"\nLoaded {len(documents)} valid documents.")
    return documents, filenames

# Train or Load Classifier
def TrainSampleClassifier():
    # Sample training data
    data = [
        ("This agreement is made between the parties...", "contract"),
        ("Your electricity usage this month is 250 kWh.", "bill"),
        ("The contract term shall be effective until...", "contract"),
        ("Meter reading: 350 kWh. Amount due: $90.25", "bill"),
        ("This contract is made between...", "contract"),
        ("Invoice number: 12345, payment due...", 'bill'),
        ("The agreement shall remain valid for...", 'contract'),
        ("Electricity consumption details for March...", 'bill')
    ]
    texts, labels = zip(*data)

    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(texts)

    clf = MultinomialNB()
    clf.fit(X, labels)

    # Save model and vectorizer
    joblib.dump(clf, "doc_classifier.joblib")
    joblib.dump(vectorizer, "tfidf_vectorizer.joblib")

# Run Classification
def ClassifyDocuments(documents):
    clf = joblib.load("doc_classifier.joblib")
    vectorizer = joblib.load("tfidf_vectorizer.joblib")

    X = vectorizer.transform(documents)
    preds = clf.predict(X)
    return preds

# Main Execution
if __name__ == "__main__":
    folder_path = "../data/raw_data"
    documents, filenames = LoadValidDocuments(folder_path)

    # Train the classifier
    TrainSampleClassifier()

    # Classify the documents loaded
    predictions = ClassifyDocuments(documents)

    # Output classification results
    for fname, pred in zip(filenames, predictions):
        print(f"{fname} -> Predicted category: {pred}")
# Out:
# Processing: document_459.pdf
# Skipping: document_459.pdf (No text extracted)
# Processing: document_317.pdf
# Processing: document_471.pdf
# Processing: document_465.pdf
# Processing: document_303.pdf
# Processing: document_854.pdf
# Processing: document_1105.pdf
# Processing: document_840.pdf
# Processing: document_1111.pdf
# Skipping: document_1111.pdf (No text extracted)
# Processing: document_698.pdf
# Skipping: document_698.pdf (No text extracted)
# Processing: document_868.pdf
# Skipping: document_868.pdf (No text extracted)
# Processing: document_1139.pdf
# Processing: document_897.pdf
# Skipping: document_897.pdf (No text extracted)
# Processing: document_129.pdf
# Skipping: document_129.pdf (No text extracted)
# Processing: document_883.pdf
# Skipping: document_883.pdf (No text extracted)
# Processing: document_673.pdf
# Processing: document_115.pdf
# Skipping: document_115.pdf (No text extracted)
# Processing: document_101.pdf
# Processing: document_667.pdf
# Processing: document_1071.pdf
# Skipping: document_1071.pdf (No text extracted)
# Processing: document_920.pdf
# Processing: document_1065.pdf
# Processing: document_934.pdf
# Skipping: document_934.pdf (No text extracted)
# Processing: document_1059.pdf
# Skipping: document_1059.pdf (No text extracted)
# Processing: document_908.pdf
# Skipping: document_908.pdf (No text extracted)
# Processing: document_707.pdf
# Processing: document_713.pdf
# Skipping: document_713.pdf (No text extracted)
# Processing: document_288.pdf
# Processing: document_12.pdf
# Skipping: document_12.pdf (No text extracted)
# Processing: document_539.pdf
# Processing: document_263.pdf
# Processing: document_505.pdf
# Processing: document_511.pdf
# Processing: document_277.pdf
# Processing: document_510.pdf
# Processing: document_276.pdf
# Processing: document_262.pdf
# Processing: document_504.pdf
# Processing: document_538.pdf
# Skipping: document_538.pdf (No text extracted)
# Processing: document_13.pdf
# Skipping: document_13.pdf (No text extracted)
# Processing: document_289.pdf
# Processing: document_712.pdf
# Processing: document_706.pdf
# Skipping: document_706.pdf (No text extracted)
# Processing: document_909.pdf
# Skipping: document_909.pdf (No text extracted)
# Processing: document_1058.pdf
# Processing: document_935.pdf
# Skipping: document_935.pdf (No text extracted)
# Processing: document_1064.pdf
# Processing: document_921.pdf
# Processing: document_1070.pdf
# Processing: document_100.pdf
# Processing: document_666.pdf
# Processing: document_672.pdf
# Processing: document_114.pdf
# Processing: document_882.pdf
# Processing: document_896.pdf
# Processing: document_128.pdf
# Skipping: document_128.pdf (No text extracted)
# Processing: document_1138.pdf
# Processing: document_869.pdf
# Skipping: document_869.pdf (No text extracted)
# Processing: document_1110.pdf
# Skipping: document_1110.pdf (No text extracted)
# Processing: document_699.pdf
# Skipping: document_699.pdf (No text extracted)
# Processing: document_841.pdf
# Processing: document_1104.pdf
# Processing: document_855.pdf
# Processing: document_464.pdf
# Processing: document_302.pdf
# Processing: document_316.pdf
# Processing: document_470.pdf
# Processing: document_458.pdf
# Skipping: document_458.pdf (No text extracted)
# Processing: document_499.pdf
# Processing: document_328.pdf
# Processing: document_300.pdf
# Processing: document_466.pdf
# Processing: document_472.pdf
# Processing: document_314.pdf
# Processing: document_843.pdf
# Processing: document_1112.pdf
# Skipping: document_1112.pdf (No text extracted)
# Processing: document_857.pdf
# Processing: document_1106.pdf
# Processing: document_658.pdf
# Processing: document_880.pdf
# Skipping: document_880.pdf (No text extracted)
# Processing: document_894.pdf
# Skipping: document_894.pdf (No text extracted)
# Processing: document_664.pdf
# Processing: document_102.pdf
# Processing: document_116.pdf
# Processing: document_670.pdf
# Processing: document_1066.pdf
# Processing: document_937.pdf
# Skipping: document_937.pdf (No text extracted)
# Processing: document_1072.pdf
# Processing: document_923.pdf
# Processing: document_738.pdf
# Processing: document_710.pdf
# Skipping: document_710.pdf (No text extracted)
# Processing: document_1099.pdf
# Processing: document_704.pdf
# Skipping: document_704.pdf (No text extracted)
# Processing: document_39.pdf
# Processing: document_11.pdf
# Skipping: document_11.pdf (No text extracted)
# Processing: document_248.pdf
# Processing: document_274.pdf
# Processing: document_512.pdf
# Processing: document_506.pdf
# Processing: document_260.pdf
# Processing: document_507.pdf
# Processing: document_261.pdf
# Processing: document_275.pdf
# Processing: document_513.pdf
# Processing: document_249.pdf
# Processing: document_10.pdf
# Skipping: document_10.pdf (No text extracted)
# Processing: document_38.pdf
# Processing: document_705.pdf
# Skipping: document_705.pdf (FileDataError: Failed to open file '../data/raw_data/document_705.pdf'.)
# Processing: document_711.pdf
# Skipping: document_711.pdf (No text extracted)
# Processing: document_1098.pdf
# Processing: document_739.pdf
# Skipping: document_739.pdf (FileDataError: Failed to open file '../data/raw_data/document_739.pdf'.)
# Processing: document_922.pdf
# Skipping: document_922.pdf (No text extracted)
# Processing: document_1073.pdf
# Skipping: document_1073.pdf (No text extracted)
# Processing: document_936.pdf
# Skipping: document_936.pdf (No text extracted)
# Processing: document_1067.pdf
# Processing: document_117.pdf
# Skipping: document_117.pdf (No text extracted)
# Processing: document_671.pdf
# Processing: document_665.pdf
# Processing: document_103.pdf
# Processing: document_895.pdf
# Skipping: document_895.pdf (No text extracted)
# Processing: document_881.pdf
# Skipping: document_881.pdf (No text extracted)
# Processing: document_659.pdf
# Skipping: document_659.pdf (No text extracted)
# Processing: document_1107.pdf
# Processing: document_856.pdf
# Processing: document_1113.pdf
# Skipping: document_1113.pdf (No text extracted)
# Processing: document_842.pdf
# Processing: document_473.pdf
# Processing: document_315.pdf
# Processing: document_301.pdf
# Processing: document_467.pdf
# Processing: document_329.pdf
# Processing: document_498.pdf
# Skipping: document_498.pdf (No text extracted)
# Processing: document_488.pdf
# Processing: document_463.pdf
# Processing: document_305.pdf
# Processing: document_311.pdf
# Processing: document_477.pdf
# Processing: document_339.pdf
# Skipping: document_339.pdf (No text extracted)
# Processing: document_846.pdf
# Processing: document_1117.pdf
# Skipping: document_1117.pdf (No text extracted)
# Processing: document_852.pdf
# Processing: document_1103.pdf
# Processing: document_107.pdf
# Processing: document_661.pdf
# Processing: document_675.pdf
# Processing: document_113.pdf
# Skipping: document_113.pdf (No text extracted)
# Processing: document_885.pdf
# Skipping: document_885.pdf (No text extracted)
# Processing: document_649.pdf
# Processing: document_891.pdf
# Skipping: document_891.pdf (No text extracted)
# Processing: document_1063.pdf
# Processing: document_932.pdf
# Skipping: document_932.pdf (No text extracted)
# Processing: document_1077.pdf
# Processing: document_926.pdf
# Skipping: document_926.pdf (No text extracted)
# Processing: document_715.pdf
# Skipping: document_715.pdf (No text extracted)
# Processing: document_701.pdf
# Skipping: document_701.pdf (No text extracted)
# Processing: document_1088.pdf
# Processing: document_729.pdf
# Processing: document_14.pdf
# Skipping: document_14.pdf (No text extracted)
# Processing: document_28.pdf
# Processing: document_517.pdf
# Processing: document_271.pdf
# Processing: document_265.pdf
# Processing: document_503.pdf
# Processing: document_259.pdf
# Processing: document_258.pdf
# Processing: document_264.pdf
# Processing: document_502.pdf
# Processing: document_516.pdf
# Processing: document_270.pdf
# Processing: document_29.pdf
# Skipping: document_29.pdf (No text extracted)
# Processing: document_15.pdf
# Skipping: document_15.pdf (No text extracted)
# Processing: document_728.pdf
# Skipping: document_728.pdf (No text extracted)
# Processing: document_700.pdf
# Skipping: document_700.pdf (No text extracted)
# Processing: document_1089.pdf
# Processing: document_714.pdf
# Processing: document_927.pdf
# Skipping: document_927.pdf (No text extracted)
# Processing: document_1076.pdf
# Skipping: document_1076.pdf (No text extracted)
# Processing: document_933.pdf
# Skipping: document_933.pdf (No text extracted)
# Processing: document_1062.pdf
# Skipping: document_1062.pdf (No text extracted)
# Processing: document_890.pdf
# Processing: document_648.pdf
# Processing: document_884.pdf
# Skipping: document_884.pdf (No text extracted)
# Processing: document_674.pdf
# Processing: document_112.pdf
# Processing: document_106.pdf
# Skipping: document_106.pdf (FileDataError: Failed to open file '../data/raw_data/document_106.pdf'.)
# Processing: document_660.pdf
# Skipping: document_660.pdf (No text extracted)
# Processing: document_1102.pdf
# Processing: document_853.pdf
# Processing: document_1116.pdf
# Skipping: document_1116.pdf (No text extracted)
# Processing: document_847.pdf
# Processing: document_338.pdf
# Processing: document_310.pdf
# Processing: document_476.pdf
# Processing: document_462.pdf
# Skipping: document_462.pdf (No text extracted)
# Processing: document_304.pdf
# Processing: document_489.pdf
# Processing: document_474.pdf
# Processing: document_312.pdf
# Processing: document_306.pdf
# Processing: document_460.pdf
# Skipping: document_460.pdf (No text extracted)
# Processing: document_448.pdf
# Skipping: document_448.pdf (No text extracted)
# Processing: document_879.pdf
# Skipping: document_879.pdf (No text extracted)
# Processing: document_1128.pdf
# Skipping: document_1128.pdf (No text extracted)
# Processing: document_851.pdf
# Processing: document_1100.pdf
# Processing: document_689.pdf
# Processing: document_845.pdf
# Processing: document_1114.pdf
# Processing: document_110.pdf
# Processing: document_676.pdf
# Processing: document_662.pdf
# Processing: document_104.pdf
# Processing: document_892.pdf
# Processing: document_886.pdf
# Processing: document_138.pdf
# Processing: document_1048.pdf
# Skipping: document_1048.pdf (No text extracted)
# Processing: document_919.pdf
# Skipping: document_919.pdf (No text extracted)
# Processing: document_1074.pdf
# Skipping: document_1074.pdf (No text extracted)
# Processing: document_925.pdf
# Skipping: document_925.pdf (No text extracted)
# Processing: document_1060.pdf
# Skipping: document_1060.pdf (No text extracted)
# Processing: document_931.pdf
# Skipping: document_931.pdf (No text extracted)
# Processing: document_702.pdf
# Skipping: document_702.pdf (No text extracted)
# Processing: document_716.pdf
# Skipping: document_716.pdf (No text extracted)
# Processing: document_17.pdf
# Processing: document_299.pdf
# Processing: document_500.pdf
# Skipping: document_500.pdf (No text extracted)
# Processing: document_266.pdf
# Processing: document_272.pdf
# Processing: document_514.pdf
# Processing: document_528.pdf
# Skipping: document_528.pdf (No text extracted)
# Processing: document_529.pdf
# Processing: document_273.pdf
# Processing: document_515.pdf
# Processing: document_501.pdf
# Skipping: document_501.pdf (No text extracted)
# Processing: document_267.pdf
# Processing: document_298.pdf
# Processing: document_16.pdf
# Skipping: document_16.pdf (No text extracted)
# Processing: document_717.pdf
# Skipping: document_717.pdf (No text extracted)
# Processing: document_703.pdf
# Processing: document_930.pdf
# Skipping: document_930.pdf (No text extracted)
# Processing: document_1061.pdf
# Processing: document_924.pdf
# Skipping: document_924.pdf (No text extracted)
# Processing: document_1075.pdf
# Processing: document_918.pdf
# Processing: document_1049.pdf
# Skipping: document_1049.pdf (No text extracted)
# Processing: document_887.pdf
# Processing: document_139.pdf
# Processing: document_893.pdf
# Skipping: document_893.pdf (No text extracted)
# Processing: document_663.pdf
# Skipping: document_663.pdf (No text extracted)
# Processing: document_105.pdf
# Processing: document_111.pdf
# Skipping: document_111.pdf (No text extracted)
# Processing: document_677.pdf
# Processing: document_1115.pdf
# Skipping: document_1115.pdf (FileDataError: Failed to open file '../data/raw_data/document_1115.pdf'.)
# Processing: document_844.pdf
# Processing: document_1101.pdf
# Processing: document_688.pdf
# Processing: document_850.pdf
# Processing: document_1129.pdf
# Processing: document_878.pdf
# Processing: document_449.pdf
# Processing: document_307.pdf
# Processing: document_461.pdf
# Skipping: document_461.pdf (No text extracted)
# Processing: document_475.pdf
# Processing: document_313.pdf
# Processing: document_348.pdf
# Processing: document_412.pdf
# Processing: document_374.pdf
# Processing: document_360.pdf
# Processing: document_406.pdf
# Processing: document_189.pdf
# Skipping: document_189.pdf (No text extracted)
# Processing: document_837.pdf
# Processing: document_1166.pdf
# Processing: document_823.pdf
# Processing: document_638.pdf
# Processing: document_176.pdf
# Skipping: document_176.pdf (No text extracted)
# Processing: document_610.pdf
# Processing: document_604.pdf
# Processing: document_0.pdf
# Skipping: document_0.pdf (No text extracted)
# Processing: document_162.pdf
# Skipping: document_162.pdf (No text extracted)
# Processing: document_1012.pdf
# Processing: document_943.pdf
# Skipping: document_943.pdf (No text extracted)
# Processing: document_1006.pdf
# Processing: document_957.pdf
# Processing: document_980.pdf
# Skipping: document_980.pdf (No text extracted)
# Processing: document_758.pdf
# Skipping: document_758.pdf (No text extracted)
# Processing: document_994.pdf
# Skipping: document_994.pdf (No text extracted)
# Processing: document_764.pdf
# Processing: document_770.pdf
# Skipping: document_770.pdf (No text extracted)
# Processing: document_599.pdf
# Processing: document_59.pdf
# Processing: document_65.pdf
# Skipping: document_65.pdf (No text extracted)
# Processing: document_71.pdf
# Skipping: document_71.pdf (No text extracted)
# Processing: document_228.pdf
# Skipping: document_228.pdf (No text extracted)
# Processing: document_566.pdf
# Processing: document_200.pdf
# Processing: document_214.pdf
# Processing: document_572.pdf
# Skipping: document_572.pdf (No text extracted)
# Processing: document_215.pdf
# Processing: document_573.pdf
# Processing: document_567.pdf
# Processing: document_201.pdf
# Processing: document_229.pdf
# Skipping: document_229.pdf (No text extracted)
# Processing: document_70.pdf
# Skipping: document_70.pdf (No text extracted)
# Processing: document_64.pdf
# Processing: document_58.pdf
# Skipping: document_58.pdf (No text extracted)
# Processing: document_598.pdf
# Skipping: document_598.pdf (No text extracted)
# Processing: document_771.pdf
# Skipping: document_771.pdf (No text extracted)
# Processing: document_765.pdf
# Skipping: document_765.pdf (No text extracted)
# Processing: document_995.pdf
# Skipping: document_995.pdf (No text extracted)
# Processing: document_759.pdf
# Skipping: document_759.pdf (No text extracted)
# Processing: document_981.pdf
# Processing: document_956.pdf
# Skipping: document_956.pdf (No text extracted)
# Processing: document_1007.pdf
# Skipping: document_1007.pdf (No text extracted)
# Processing: document_942.pdf
# Skipping: document_942.pdf (No text extracted)
# Processing: document_1013.pdf
# Skipping: document_1013.pdf (No text extracted)
# Processing: document_1.pdf
# Skipping: document_1.pdf (No text extracted)
# Processing: document_605.pdf
# Processing: document_163.pdf
# Skipping: document_163.pdf (No text extracted)
# Processing: document_177.pdf
# Skipping: document_177.pdf (No text extracted)
# Processing: document_611.pdf
# Processing: document_639.pdf
# Skipping: document_639.pdf (No text extracted)
# Processing: document_822.pdf
# Processing: document_188.pdf
# Processing: document_1167.pdf
# Skipping: document_1167.pdf (No text extracted)
# Processing: document_836.pdf
# Processing: document_361.pdf
# Processing: document_407.pdf
# Processing: document_413.pdf
# Processing: document_375.pdf
# Skipping: document_375.pdf (No text extracted)
# Processing: document_349.pdf
# Processing: document_388.pdf
# Processing: document_439.pdf
# Processing: document_405.pdf
# Processing: document_363.pdf
# Processing: document_377.pdf
# Processing: document_411.pdf
# Processing: document_820.pdf
# Skipping: document_820.pdf (No text extracted)
# Processing: document_834.pdf
# Processing: document_1165.pdf
# Skipping: document_1165.pdf (No text extracted)
# Processing: document_808.pdf
# Processing: document_1159.pdf
# Skipping: document_1159.pdf (No text extracted)
# Processing: document_149.pdf
# Processing: document_161.pdf
# Skipping: document_161.pdf (No text extracted)
# Processing: document_607.pdf
# Processing: document_3.pdf
# Skipping: document_3.pdf (No text extracted)
# Processing: document_613.pdf
# Processing: document_175.pdf
# Skipping: document_175.pdf (No text extracted)
# Processing: document_1005.pdf
# Skipping: document_1005.pdf (No text extracted)
# Processing: document_954.pdf
# Processing: document_1011.pdf
# Processing: document_798.pdf
# Skipping: document_798.pdf (No text extracted)
# Processing: document_940.pdf
# Skipping: document_940.pdf (No text extracted)
# Processing: document_1039.pdf
# Skipping: document_1039.pdf (No text extracted)
# Processing: document_968.pdf
# Processing: document_997.pdf
# Skipping: document_997.pdf (No text extracted)
# Processing: document_983.pdf
# Processing: document_773.pdf
# Skipping: document_773.pdf (No text extracted)
# Processing: document_767.pdf
# Skipping: document_767.pdf (No text extracted)
# Processing: document_72.pdf
# Skipping: document_72.pdf (No text extracted)
# Processing: document_66.pdf
# Skipping: document_66.pdf (No text extracted)
# Processing: document_559.pdf
# Skipping: document_559.pdf (No text extracted)
# Processing: document_99.pdf
# Processing: document_571.pdf
# Skipping: document_571.pdf (No text extracted)
# Processing: document_217.pdf
# Processing: document_203.pdf
# Skipping: document_203.pdf (No text extracted)
# Processing: document_565.pdf
# Processing: document_202.pdf
# Processing: document_564.pdf
# Processing: document_570.pdf
# Skipping: document_570.pdf (No text extracted)
# Processing: document_216.pdf
# Processing: document_98.pdf
# Processing: document_558.pdf
# Skipping: document_558.pdf (No text extracted)
# Processing: document_67.pdf
# Skipping: document_67.pdf (No text extracted)
# Processing: document_73.pdf
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (648 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (649 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (650 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (651 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (652 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (653 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (654 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (655 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (647 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (644 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (645 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# MuPDF error: format error: cannot find object in xref (646 0 R)
#
# ...
# document_208.pdf -> Predicted category: bill
# document_51.pdf -> Predicted category: contract
# document_45.pdf -> Predicted category: contract
# document_79.pdf -> Predicted category: contract
# document_988.pdf -> Predicted category: bill
# document_787.pdf -> Predicted category: contract
# document_977.pdf -> Predicted category: bill
# document_1026.pdf -> Predicted category: bill
# document_963.pdf -> Predicted category: bill
# document_1032.pdf -> Predicted category: bill
# document_624.pdf -> Predicted category: contract
# document_630.pdf -> Predicted category: contract
# document_1152.pdf -> Predicted category: bill
# document_803.pdf -> Predicted category: bill
# document_1146.pdf -> Predicted category: bill
# document_432.pdf -> Predicted category: contract
# document_383.pdf -> Predicted category: bill
# document_397.pdf -> Predicted category: bill
# document_381.pdf -> Predicted category: bill
# document_395.pdf -> Predicted category: contract
# document_418.pdf -> Predicted category: bill
# document_424.pdf -> Predicted category: contract
# document_356.pdf -> Predicted category: bill
# document_430.pdf -> Predicted category: contract
# document_801.pdf -> Predicted category: contract
# document_1150.pdf -> Predicted category: bill
# document_1144.pdf -> Predicted category: bill
# document_829.pdf -> Predicted category: bill
# document_626.pdf -> Predicted category: bill
# document_632.pdf -> Predicted category: bill
# document_1024.pdf -> Predicted category: bill
# document_975.pdf -> Predicted category: bill
# document_1030.pdf -> Predicted category: bill
# document_961.pdf -> Predicted category: contract
# document_1018.pdf -> Predicted category: bill
# document_949.pdf -> Predicted category: bill
# document_752.pdf -> Predicted category: contract
# document_47.pdf -> Predicted category: contract
# document_550.pdf -> Predicted category: contract
# document_236.pdf -> Predicted category: bill
# document_84.pdf -> Predicted category: bill
# document_85.pdf -> Predicted category: bill
# document_545.pdf -> Predicted category: contract
# document_91.pdf -> Predicted category: bill
# document_551.pdf -> Predicted category: contract
# document_237.pdf -> Predicted category: bill
# document_586.pdf -> Predicted category: contract
# document_592.pdf -> Predicted category: contract
# document_753.pdf -> Predicted category: contract
# document_1019.pdf -> Predicted category: contract
# document_1031.pdf -> Predicted category: bill
# document_974.pdf -> Predicted category: bill
# document_1025.pdf -> Predicted category: bill
# document_155.pdf -> Predicted category: contract
# document_141.pdf -> Predicted category: contract
# document_627.pdf -> Predicted category: bill
# document_828.pdf -> Predicted category: bill
# document_196.pdf -> Predicted category: bill
# document_1145.pdf -> Predicted category: bill
# document_814.pdf -> Predicted category: bill
# document_1151.pdf -> Predicted category: bill
# document_800.pdf -> Predicted category: bill
# document_357.pdf -> Predicted category: bill
# document_419.pdf -> Predicted category: bill
# document_380.pdf -> Predicted category: bill
# document_384.pdf -> Predicted category: contract
# document_390.pdf -> Predicted category: bill
# document_347.pdf -> Predicted category: bill
# document_421.pdf -> Predicted category: contract
# document_435.pdf -> Predicted category: bill
# document_353.pdf -> Predicted category: bill
# document_409.pdf -> Predicted category: contract
# document_838.pdf -> Predicted category: bill
# document_1169.pdf -> Predicted category: contract
# document_192.pdf -> Predicted category: bill
# document_804.pdf -> Predicted category: bill
# document_1155.pdf -> Predicted category: bill
# document_810.pdf -> Predicted category: bill
# document_145.pdf -> Predicted category: contract
# document_151.pdf -> Predicted category: bill
# document_1009.pdf -> Predicted category: bill
# document_958.pdf -> Predicted category: contract
# document_1021.pdf -> Predicted category: bill
# document_970.pdf -> Predicted category: bill
# document_1035.pdf -> Predicted category: contract
# document_964.pdf -> Predicted category: bill
# document_42.pdf -> Predicted category: bill
# document_233.pdf -> Predicted category: bill
# document_555.pdf -> Predicted category: contract
# document_81.pdf -> Predicted category: contract
# document_541.pdf -> Predicted category: contract
# document_569.pdf -> Predicted category: bill
# document_568.pdf -> Predicted category: bill
# document_540.pdf -> Predicted category: bill
# document_80.pdf -> Predicted category: bill
# document_554.pdf -> Predicted category: bill
# document_94.pdf -> Predicted category: bill
# document_43.pdf -> Predicted category: contract
# document_57.pdf -> Predicted category: bill
# document_965.pdf -> Predicted category: contract
# document_971.pdf -> Predicted category: bill
# document_1020.pdf -> Predicted category: bill
# document_1008.pdf -> Predicted category: contract
# document_150.pdf -> Predicted category: bill
# document_636.pdf -> Predicted category: bill
# document_144.pdf -> Predicted category: bill
# document_811.pdf -> Predicted category: bill
# document_1154.pdf -> Predicted category: bill
# document_805.pdf -> Predicted category: bill
# document_1168.pdf -> Predicted category: contract
# document_839.pdf -> Predicted category: bill
# document_187.pdf -> Predicted category: bill
# document_408.pdf -> Predicted category: contract
# document_434.pdf -> Predicted category: contract
# document_352.pdf -> Predicted category: bill
# document_346.pdf -> Predicted category: bill
# document_420.pdf -> Predicted category: bill
# document_391.pdf -> Predicted category: contract
# document_385.pdf -> Predicted category: bill
# document_393.pdf -> Predicted category: contract
# document_350.pdf -> Predicted category: bill
# document_436.pdf -> Predicted category: bill
# document_422.pdf -> Predicted category: contract
# document_344.pdf -> Predicted category: bill
# document_378.pdf -> Predicted category: bill
# document_807.pdf -> Predicted category: bill
# document_634.pdf -> Predicted category: bill
# document_152.pdf -> Predicted category: bill
# document_146.pdf -> Predicted category: bill
# document_608.pdf -> Predicted category: bill
# document_797.pdf -> Predicted category: contract
# document_967.pdf -> Predicted category: bill
# document_1022.pdf -> Predicted category: bill
# document_973.pdf -> Predicted category: bill
# document_998.pdf -> Predicted category: contract
# document_754.pdf -> Predicted category: bill
# document_41.pdf -> Predicted category: bill
# document_55.pdf -> Predicted category: bill
# document_82.pdf -> Predicted category: bill
# document_542.pdf -> Predicted category: bill
# document_96.pdf -> Predicted category: bill
# document_557.pdf -> Predicted category: contract
# document_97.pdf -> Predicted category: bill
# document_543.pdf -> Predicted category: contract
# document_40.pdf -> Predicted category: bill
# document_972.pdf -> Predicted category: bill
# document_1023.pdf -> Predicted category: bill
# document_966.pdf -> Predicted category: contract
# document_1037.pdf -> Predicted category: contract
# document_609.pdf -> Predicted category: bill
# document_147.pdf -> Predicted category: contract
# document_806.pdf -> Predicted category: bill
# document_190.pdf -> Predicted category: bill
# document_423.pdf -> Predicted category: bill
# document_345.pdf -> Predicted category: bill
# document_351.pdf -> Predicted category: bill
# document_437.pdf -> Predicted category: bill
# document_386.pdf -> Predicted category: contract
# document_392.pdf -> Predicted category: contract
# document_493.pdf -> Predicted category: bill
# document_478.pdf -> Predicted category: bill
# document_336.pdf -> Predicted category: contract
# document_450.pdf -> Predicted category: contract
# document_322.pdf -> Predicted category: bill
# document_875.pdf -> Predicted category: bill
# document_861.pdf -> Predicted category: bill
# document_849.pdf -> Predicted category: bill
# document_685.pdf -> Predicted category: bill
# document_108.pdf -> Predicted category: contract
# document_652.pdf -> Predicted category: contract
# document_120.pdf -> Predicted category: contract
# document_646.pdf -> Predicted category: bill
# document_1044.pdf -> Predicted category: bill
# document_915.pdf -> Predicted category: contract
# document_1093.pdf -> Predicted category: bill
# document_1087.pdf -> Predicted category: bill
# document_732.pdf -> Predicted category: bill
# document_281.pdf -> Predicted category: bill
# document_295.pdf -> Predicted category: bill
# document_518.pdf -> Predicted category: contract
# document_242.pdf -> Predicted category: bill
# document_256.pdf -> Predicted category: bill
# document_531.pdf -> Predicted category: contract
# document_257.pdf -> Predicted category: bill
# document_243.pdf -> Predicted category: bill
# document_525.pdf -> Predicted category: contract
# document_519.pdf -> Predicted category: contract
# document_294.pdf -> Predicted category: bill
# document_280.pdf -> Predicted category: bill
# document_733.pdf -> Predicted category: bill
# document_727.pdf -> Predicted category: bill
# document_1092.pdf -> Predicted category: bill
# document_1079.pdf -> Predicted category: bill
# document_914.pdf -> Predicted category: contract
# document_1045.pdf -> Predicted category: contract
# document_900.pdf -> Predicted category: bill
# document_647.pdf -> Predicted category: contract
# document_653.pdf -> Predicted category: contract
# document_1119.pdf -> Predicted category: contract
# document_848.pdf -> Predicted category: bill
# document_1131.pdf -> Predicted category: contract
# document_860.pdf -> Predicted category: contract
# document_323.pdf -> Predicted category: bill
# document_479.pdf -> Predicted category: bill
# document_486.pdf -> Predicted category: bill
# document_492.pdf -> Predicted category: bill
# document_484.pdf -> Predicted category: bill
# document_490.pdf -> Predicted category: bill
# document_309.pdf -> Predicted category: bill
# document_321.pdf -> Predicted category: bill
# document_453.pdf -> Predicted category: bill
# document_686.pdf -> Predicted category: bill
# document_679.pdf -> Predicted category: bill
# document_645.pdf -> Predicted category: contract
# document_137.pdf -> Predicted category: contract
# document_651.pdf -> Predicted category: contract
# document_916.pdf -> Predicted category: bill
# document_1084.pdf -> Predicted category: contract
# document_719.pdf -> Predicted category: bill
# document_1090.pdf -> Predicted category: bill
# document_731.pdf -> Predicted category: contract
# document_296.pdf -> Predicted category: bill
# document_24.pdf -> Predicted category: contract
# document_282.pdf -> Predicted category: bill
# document_269.pdf -> Predicted category: bill
# document_255.pdf -> Predicted category: bill
# document_527.pdf -> Predicted category: contract
# document_241.pdf -> Predicted category: bill
# document_526.pdf -> Predicted category: bill
# document_240.pdf -> Predicted category: bill
# document_254.pdf -> Predicted category: bill
# document_268.pdf -> Predicted category: bill
# document_283.pdf -> Predicted category: bill
# document_297.pdf -> Predicted category: bill
# document_724.pdf -> Predicted category: bill
# document_730.pdf -> Predicted category: bill
# document_718.pdf -> Predicted category: contract
# document_1091.pdf -> Predicted category: bill
# document_888.pdf -> Predicted category: bill
# document_650.pdf -> Predicted category: bill
# document_644.pdf -> Predicted category: bill
# document_678.pdf -> Predicted category: bill
# document_687.pdf -> Predicted category: bill
# document_863.pdf -> Predicted category: bill
# document_320.pdf -> Predicted category: bill
# document_308.pdf -> Predicted category: bill
# document_491.pdf -> Predicted category: contract
# document_485.pdf -> Predicted category: bill
# document_481.pdf -> Predicted category: bill
# document_495.pdf -> Predicted category: bill
# document_442.pdf -> Predicted category: bill
# document_324.pdf -> Predicted category: contract
# document_330.pdf -> Predicted category: bill
# document_456.pdf -> Predicted category: contract
# document_318.pdf -> Predicted category: bill
# document_683.pdf -> Predicted category: bill
# document_867.pdf -> Predicted category: bill
# document_873.pdf -> Predicted category: bill
# document_640.pdf -> Predicted category: bill
# document_898.pdf -> Predicted category: bill
# document_654.pdf -> Predicted category: contract
# document_668.pdf -> Predicted category: bill
# document_913.pdf -> Predicted category: bill
# document_734.pdf -> Predicted category: bill
# document_720.pdf -> Predicted category: contract
# document_1081.pdf -> Predicted category: bill
# document_1095.pdf -> Predicted category: bill
# document_293.pdf -> Predicted category: bill
# document_287.pdf -> Predicted category: bill
# document_250.pdf -> Predicted category: bill
# document_244.pdf -> Predicted category: bill
# document_522.pdf -> Predicted category: contract
# document_278.pdf -> Predicted category: bill
# document_279.pdf -> Predicted category: bill
# document_245.pdf -> Predicted category: bill
# document_523.pdf -> Predicted category: contract
# document_537.pdf -> Predicted category: contract
# document_251.pdf -> Predicted category: bill
# document_286.pdf -> Predicted category: bill
# document_292.pdf -> Predicted category: bill
# document_1094.pdf -> Predicted category: bill
# document_1080.pdf -> Predicted category: contract
# document_735.pdf -> Predicted category: bill
# document_906.pdf -> Predicted category: contract
# document_912.pdf -> Predicted category: contract
# document_1043.pdf -> Predicted category: contract
# document_669.pdf -> Predicted category: bill
# document_655.pdf -> Predicted category: contract
# document_899.pdf -> Predicted category: bill
# document_872.pdf -> Predicted category: bill
# document_866.pdf -> Predicted category: bill
# document_682.pdf -> Predicted category: bill
# document_319.pdf -> Predicted category: bill
# document_457.pdf -> Predicted category: contract
# document_325.pdf -> Predicted category: contract
# document_494.pdf -> Predicted category: bill
# document_480.pdf -> Predicted category: bill
# document_496.pdf -> Predicted category: bill
# document_482.pdf -> Predicted category: bill
# document_327.pdf -> Predicted category: contract
# document_441.pdf -> Predicted category: bill
# document_469.pdf -> Predicted category: bill
# document_858.pdf -> Predicted category: contract
# document_680.pdf -> Predicted category: bill
# document_870.pdf -> Predicted category: bill
# document_1121.pdf -> Predicted category: contract
# document_864.pdf -> Predicted category: bill
# document_643.pdf -> Predicted category: contract
# document_904.pdf -> Predicted category: contract
# document_723.pdf -> Predicted category: contract
# document_1096.pdf -> Predicted category: bill
# document_1082.pdf -> Predicted category: contract
# document_22.pdf -> Predicted category: bill
# document_284.pdf -> Predicted category: bill
# document_290.pdf -> Predicted category: bill
# document_36.pdf -> Predicted category: bill
# document_521.pdf -> Predicted category: contract
# document_247.pdf -> Predicted category: bill
# document_253.pdf -> Predicted category: bill
# document_509.pdf -> Predicted category: bill
# document_508.pdf -> Predicted category: bill
# document_252.pdf -> Predicted category: bill
# document_520.pdf -> Predicted category: contract
# document_246.pdf -> Predicted category: bill
# document_291.pdf -> Predicted category: bill
# document_37.pdf -> Predicted category: bill
# document_23.pdf -> Predicted category: contract
# document_285.pdf -> Predicted category: bill
# document_1097.pdf -> Predicted category: bill
# document_736.pdf -> Predicted category: contract
# document_1054.pdf -> Predicted category: bill
# document_1068.pdf -> Predicted category: bill
# document_118.pdf -> Predicted category: contract
# document_642.pdf -> Predicted category: bill
# document_656.pdf -> Predicted category: contract
# document_871.pdf -> Predicted category: bill
# document_1108.pdf -> Predicted category: contract
# document_681.pdf -> Predicted category: bill
# document_859.pdf -> Predicted category: contract
# document_468.pdf -> Predicted category: contract
# document_326.pdf -> Predicted category: contract
# document_440.pdf -> Predicted category: bill
# document_454.pdf -> Predicted category: contract
# document_483.pdf -> Predicted category: bill
# document_497.pdf -> Predicted category: contract

# %%
from collections import Counter

# %%
Counter(predictions)
# Out:
# Counter({'bill': 485, 'contract': 206})

# %%
# Show sample output of loaded documents
for i, (name, text) in enumerate(zip(filenames, documents[:3])):
    print(f"--- Document {i+1}: {name} ---\n{text[:500]}...\n")
# Out:
# --- Document 1: document_317.pdf ---
# 1 M
# J
# EVERSSURCE
# Total Amount Due
# by 02/16/24
# $2,222.16
# Account Number:
# Statement Date:
# Service Provided To:
# TOWN OF BERLIN
# 5160 051 3022
# 12/18/23
# j Amount Due 0n12/11/23
# j Last Payment Received On 11/15/23
# I Balance Forward
# E Total Current Charges
# $2,376.90
# -$1,162.11
# ■^,007.37
# Electric Usage History - Kilowatt Hours (kwh)
# Current Charges for Electricity
# Supply
# $422.39
# Delivery
# $584.98
# kWWOay
# 350-1
# 300-
# Costof electricity from NEXTERA
# ENERGY SERVICES CONN
# Cost to deliver electricity
# from Everso...
#
# --- Document 2: document_471.pdf ---
# Account Number:
# Amount Enclosed
# Please make your check payable to Eversource and consider adding $1 for Good Neighbor.
# WM_230404PROD.TXT
# You may be subject to a 1.02% late payment charge if
# the "Total Amount Due" is not received by 04/29/23
# Eversource
# PO Box 56005
# Boston, MA 02205-6005
# 5441420701937 0011569675 0000120463
# Visit Eversource.com to make your payment today. If mailing payment, please allow up to 5 business days to post.
# Remit Payment To: Eversource, PO Box 56005, Boston, MA 02205-600...
#
# --- Document 3: document_465.pdf ---
# Account Number:
# Amount Enclosed
# Please make your check payable to Eversource and consider adding $1 for Good Neighbor.
# WM_230413PROD.TXT
# You may be subject to a 1.02% late payment charge if
# the "Total Amount Due" is not received by 05/08/23
# Eversource
# PO Box 56005
# Boston, MA 02205-6005
# 5454840207241 0000325257 0000325257
# Visit Eversource.com to make your payment today. If mailing payment, please allow up to 5 business days to post.
# Remit Payment To: Eversource, PO Box 56005, Boston, MA 02205-600...
